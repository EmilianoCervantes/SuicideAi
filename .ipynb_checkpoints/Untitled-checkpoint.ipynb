# %%
#Encodear palabras
import codecs
#Regex para expresiones
import glob
#Remueve Acentos
import unidecode
#Concurrency para el analisis
import multiprocessing
#Operaciones de sistema
import os
#Impresion con formato
import pprint
#Expresiones regulares
import re
#Lenguaje Natural
import nltk
#Word2Vec
import gensim.models.word2vec as w2v
#Reduccion de dimensiones y normalizacion
import sklearn.manifold
#Matematica
import numpy as np
#Plottear en una grafica
import matplotlib.pyplot as plt
#Pandas
import pandas as pd
#Visualizacion del los datos
import seaborn as sns
# Tokenizar en español
from nltk.tokenize.toktok import ToktokTokenizer
from nltk.corpus import stopwords
from math import log

# %%
nltk.download('punkt') #tokeniza las oraciones
nltk.download('stopwords') #remueve palabras como a, o, y, sobre
nltk.download('perluniprops') #tokeniza las oraciones
nltk.download('nonbreaking_prefixes') #remueve palabras como a, o, y, sobre
# Out:
# [nltk_data] Downloading package punkt to /home/frhec/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/frhec/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package perluniprops to
# [nltk_data]     /home/frhec/nltk_data...
# [nltk_data]   Package perluniprops is already up-to-date!
# [nltk_data] Downloading package nonbreaking_prefixes to
# [nltk_data]     /home/frhec/nltk_data...
# [nltk_data]   Package nonbreaking_prefixes is already up-to-date!
# True

# %%
archivos = sorted(glob.glob("/home/frhec/Documents/Anaconda/Vectorization/*.txt"))
archivos
# Out:
# ['/home/frhec/Documents/Anaconda/Vectorization/Suicida1.txt',
#  '/home/frhec/Documents/Anaconda/Vectorization/Suicida2.txt',
#  '/home/frhec/Documents/Anaconda/Vectorization/Suicida3.txt',
#  '/home/frhec/Documents/Anaconda/Vectorization/Suicida4.txt',
#  '/home/frhec/Documents/Anaconda/Vectorization/Suicida5.txt',
#  '/home/frhec/Documents/Anaconda/Vectorization/Suicida8.txt',
#  '/home/frhec/Documents/Anaconda/Vectorization/Suicidio6.txt',
#  '/home/frhec/Documents/Anaconda/Vectorization/Suicidio7.txt']

# %%
corpus_raw = u""
for archivo in archivos:
    print("Estoy leyendo el archivo {0}".format(archivo))
    with codecs.open(archivo, "r", "utf-8") as archivo:
        corpus_raw += archivo.read()
    print("El corpus tiene {0} characteres".format(len(corpus_raw)))
    print()
# Out:
# Estoy leyendo el archivo /home/frhec/Documents/Anaconda/Vectorization/Suicida1.txt
# El corpus tiene 11120 characteres
#
# Estoy leyendo el archivo /home/frhec/Documents/Anaconda/Vectorization/Suicida2.txt
# El corpus tiene 20110 characteres
#
# Estoy leyendo el archivo /home/frhec/Documents/Anaconda/Vectorization/Suicida3.txt
# El corpus tiene 28693 characteres
#
# Estoy leyendo el archivo /home/frhec/Documents/Anaconda/Vectorization/Suicida4.txt
# El corpus tiene 44935 characteres
#
# Estoy leyendo el archivo /home/frhec/Documents/Anaconda/Vectorization/Suicida5.txt
# El corpus tiene 49696 characteres
#
# Estoy leyendo el archivo /home/frhec/Documents/Anaconda/Vectorization/Suicida8.txt
# El corpus tiene 151797 characteres
#
# Estoy leyendo el archivo /home/frhec/Documents/Anaconda/Vectorization/Suicidio6.txt
# El corpus tiene 182917 characteres
#
# Estoy leyendo el archivo /home/frhec/Documents/Anaconda/Vectorization/Suicidio7.txt
# El corpus tiene 373324 characteres

# %%
tokenizer = nltk.data.load('tokenizers/punkt/spanish.pickle')

# %%
raw_sentences = tokenizer.tokenize(corpus_raw)

# %%
# Limpia characteres, mantiene preguntas, acentos y ñ para terminos de contexto
toktok = ToktokTokenizer()
preposiciones = ["a", "ante", "bajo", "cabe", "con", "contra", "de", "desde", "durante", "en", "entre", "hacia", "hasta", "mediante", "para", "por", "segun", "sin", "so", "sobre", "tras", "versus","via"]
articulos = ["el", "lo" ,"la", "los", "las", "esas","esa","es","que" ,"nos", "tan", "estas","ella","misma" ,"ello", "algo","cosa","pero", "como", "esta", "eres", "esas", "ha", "eh"]
symbols = re.compile(r'(\W+)', re.U)
stop = stopwords.words('spanish')

import re

contractions = re.compile(r"'|-|\"")
# single character removal
singles = re.compile(r'(\s\S\s)', re.I|re.U)
# separators (any whitespace)
seps = re.compile(r'\s+')

# cleaner (order matters)
def clean(text): 
    text = text.lower()
    text = contractions.sub('', text)
    text = singles.sub(' ', text)
    text = seps.sub(' ', text)
    return text

# sentence splitter
alteos = re.compile(r'([!\?])')
def sentences(l):
    l = alteos.sub(r' \1 .', l).rstrip("(\.)*\n")

def limpia_impureza(raw):
    texto = re.sub("[^a-zA-Zñáéíóúü]"," ",raw)
    texto = texto.lower()
    unaccented_string=unidecode.unidecode(clean(texto)).split()
    result = list(set(unaccented_string) - set(preposiciones)- set(articulos))
    important_words=[]
    for word in result:
        if word is 'no' or 'si' or word not in stop :
            important_words.append(word)
    result=' '.join(important_words)
    return toktok.tokenize(result)

# %%
sentences = []
for raw_sentence in raw_sentences:
    if len(raw_sentence) > 0:
        sentences.append(limpia_impureza(raw_sentence))

# %%
sentences
# Out:
# [['gente', 'hipocresia', 'menos', 'jodido', 'no', 'necesitas', 'dejes', 'vea'],
#  ['veian', 'nadie', 'sangre', 'no', 'muriendo', 'estaba', 'se', 'alarmo'],
#  ['torturado',
#   'ya',
#   'me',
#   'demasiado',
#   'tiempo',
#   'he',
#   'no',
#   'duele',
#   'cansa',
#   'mentalmente',
#   'mucho'],
#  ['aun',
#   'miles',
#   'asi',
#   'alrededor',
#   'solo',
#   'tu',
#   'personas',
#   'teniendo',
#   'te',
#   'sientes'],
#  ['mas', 'yo', 'me', 'lastimo', 'fuera', 'persona', 'si', 'dirias', 'te'],
#  ['sea', 'importa', 'desahogate', 'no', 'solo'],
#  ['llorar', 'morir', 'dormir', 'dejame', 'gritar', 'felicidad'],
#  ['suena', 'yo', 'hermoso', 'eso', 'imposible', 'alguien'],
#  ['decepciono', 'cada', 'verdad', 'doy', 'te', 'paso'],
#  ['mi', 'orgullosa', 'he', 'no', 'se', 'hacer', 'sientas', 'notado', 'te'],
#  ['mas',
#   'ya',
#   'unas',
#   'reir',
#   'seguir',
#   'vez',
#   'locas',
#   'ganas',
#   'cada',
#   'no',
#   'siento',
#   'matarme',
#   'puedo',
#   'dificil'],
#  ['mas', 'estoy', 'anterior', 'jodida', 'cada', 'dia'],
#  ['tener',
#   'aun',
#   'mareos',
#   'hambre',
#   'ansiedad',
#   'asi',
#   'sonreir',
#   'cabeza',
#   'dolor',
#   'depresion'],
#  ['me', 'perdido', 'oscuridad', 'mi', 'dentro', 'he'],
#  ['hago', 'todo', 'mal'],
#  ['autoestima', 'mi', 'ahora', 'antes', 'estaba', 'cielos', 'suelos'],
#  ['ya', 'sola', 'no', 'casa', 'quedarme', 'puedo'],
#  ['haga', 'temes'],
#  ['dano', 'me', 'haga'],
#  ['admitelo', 'va', 'nunca', 'esperando', 'totalmente', 'pasar'],
#  ['ironico', 'aun', 'exista', 'perfeccion', 'asi', 'no', 'palabra'],
#  ['ya', 'perdido', 'quizas', 'varios', 'he'],
#  ['realidad',
#   'sonar',
#   'final',
#   'si',
#   'sirve',
#   'al',
#   'solo',
#   'muerta',
#   'se',
#   'vuelve'],
#  ['contar',
#   'hablar',
#   'me',
#   'molestando',
#   'persona',
#   'gusta',
#   'si',
#   'otra',
#   'estuviera',
#   'ni',
#   'le',
#   'mis',
#   'siento',
#   'diera',
#   'igual',
#   'problemas',
#   'no',
#   'solo'],
#  ['todo', 'un', 'una', 'vida', 'rompecabezas', 'lugar', 'tiene', 'razon'],
#  ['insistas', 'piezas', 'donde', 'no', 'caben', 'colocar'],
#  ['mas',
#   'frases',
#   'situacion',
#   'nosotros',
#   'asegurar',
#   'si',
#   'quieres',
#   'suicidas',
#   'te',
#   'duele',
#   'no',
#   'identifican',
#   'destruye',
#   'verdad',
#   'puedo',
#   'vernos'],
#  ['die',
#   'ser',
#   'si',
#   'acostumbraran',
#   'cuando',
#   'just',
#   'siempre',
#   'acostumbras',
#   'comprendida',
#   'mio',
#   'quiero',
#   'se',
#   'lastimarte',
#   'suelos',
#   'demas',
#   'autoestima',
#   'criticada',
#   'trato',
#   'subirle',
#   'perdonar',
#   'no',
#   'want'],
#  ['mentira',
#   'quedo',
#   'siempre',
#   'atencion',
#   'cortarse',
#   'gran',
#   'actriz',
#   'querer',
#   'ni',
#   'feliz',
#   'marca',
#   'una',
#   'no',
#   'llamar',
#   'pregunta',
#   'dejo',
#   'bien',
#   'sonries',
#   'doler'],
#  ['forma', 'llorar', 'peor'],
#  ['cansaste',
#   'dentro',
#   'sueltas',
#   'sola',
#   'no',
#   'ni',
#   'una',
#   'lagrima',
#   'mueres',
#   'te',
#   'intentar'],
#  ['algun', 'va', 'todo', 'ser', 'cede', 'aqui', 'distinto', 'te', 'dia'],
#  ['podria',
#   'me',
#   'hombre',
#   'mi',
#   'fallo',
#   'si',
#   'aprendi',
#   'hacerlo',
#   'cualquier',
#   'papa'],
#  ['buena',
#   'inutil',
#   'yo',
#   'maraca',
#   'tonta',
#   'solo',
#   'suicida',
#   'rota',
#   'fea',
#   'nada'],
#  ['amores', 'son', 'cortes'],
#  ['son',
#   'otros',
#   'simplemente',
#   'poco',
#   'tiempo',
#   'se',
#   'borran',
#   'hay',
#   'algunos',
#   'profundos',
#   'marcados',
#   'quedan'],
#  ['don', 'tenemos', 'un', 'mio', 'cual', 'todos'],
#  ['comenzaba', 'todo', 'arruinar', 'ir', 'facil', 'justo', 'bien', 'cuando'],
#  ['mas',
#   'sufren',
#   'llorar',
#   'yo',
#   'persona',
#   'cuando',
#   'nadie',
#   'luego',
#   'tipo',
#   'odia',
#   'no',
#   'soy',
#   'hay',
#   'vean',
#   'bien',
#   'silencio'],
#  ['dulce', 'mierda', 'si', 'vida', 'una', 'tu'],
#  ['vacios', 'y', 'emociones', 'asi', 'rotos', 'dias', 'vida', 'pasan'],
#  ['semana',
#   'estoy',
#   'buen',
#   'mes',
#   'mal',
#   'si',
#   'llevando',
#   'disculpa',
#   'trato',
#   'un',
#   'ano',
#   'no',
#   'solo',
#   'vida',
#   'te',
#   'dia'],
#  ['tener',
#   'aun',
#   'mareos',
#   'hambre',
#   'ansiedad',
#   'asi',
#   'sonreir',
#   'cabeza',
#   'dolor',
#   'depresion'],
#  ['frases',
#   'gusta',
#   'pensamientos',
#   'estar',
#   'auto',
#   'recuerdos',
#   'lesionarnos',
#   'solos'],
#  ['sola', 'completamente', 'estoy'],
#  ['me',
#   'yo',
#   'final',
#   'da',
#   'hablo',
#   'comprendi',
#   'y',
#   'si',
#   'conecto',
#   'primero',
#   'voy',
#   'nadie',
#   'al',
#   'igual',
#   'no',
#   'clase',
#   'doy',
#   'hace'],
#  ['mas', 'estoy', 'anterior', 'jodida', 'cada', 'dia'],
#  ['yo', 'todo', 'esto', 'terminar', 'sabia', 'iba', 'peor'],
#  ['mas',
#   'me',
#   'ilusione',
#   'estupideces',
#   'persona',
#   'ser',
#   'otras',
#   'tienes',
#   'segura',
#   'delgada',
#   'te',
#   'igual',
#   'inteligente',
#   'una',
#   'muy',
#   'dicen',
#   'todos',
#   'linda',
#   'cuando',
#   'dificil'],
#  ['mas',
#   'son',
#   'otros',
#   'entenderas',
#   'mismo',
#   'nunca',
#   'entiendo',
#   'pasamos',
#   'mis',
#   'fuertes',
#   'algunos',
#   'lagrimas',
#   'todos',
#   'te',
#   'razon'],
#  ['nadie', 'quien', 'observando', 'te', 'cuando'],
#  ['me',
#   'mierda',
#   'llamando',
#   'nadie',
#   'estamos',
#   'amor',
#   'hoy',
#   'escuche',
#   'no',
#   'tengo',
#   'dia',
#   'mira',
#   'decir',
#   'entienda',
#   'mucho'],
#  ['ya', 'corazon', 'puedes', 'roto', 'romper', 'un', 'no'],
#  ['gente', 'ganas', 'mal', 'haciendo', 'sentir'],
#  ['buena',
#   'suicidio',
#   'solucion',
#   'otros',
#   'persona',
#   'era',
#   'suicidas',
#   'llegas',
#   'chicos',
#   'suicidar',
#   'no',
#   'todos',
#   'somos',
#   'una',
#   'diciendoles',
#   'dicen',
#   'insultan',
#   'te',
#   'cuando'],
#  ['sorprendas', 'me', 'algun', 'puedes', 'si', 'no', 'levantar', 'te', 'dia'],
#  ['enojan', 'tratas', 'ti', 'tratan', 'se', 'personas', 'te', 'cuando'],
#  ['cobardes', 'suicidio', 'piensas'],
#  ['intenta', 'hacerlo'],
#  ['puedes', 'no', 'verdad'],
#  ['ahora', 'quien', 'cobarde'],
#  ['tiene',
#   'cada',
#   'un',
#   'vida',
#   'rompecabezas',
#   'una',
#   'lugar',
#   'pieza',
#   'porque',
#   'razon'],
#  ['insistas', 'piezas', 'poner', 'no', 'caben', 'donde'],
#  ['mas', 'deprimirse', 'pensar', 'rapida', 'forma'],
#  ['me', 'guste', 'veo', 'miro', 'no', 'nada'],
#  ['me', 'gente', 'sola', 'feliz', 'no', 'siento', 'bien', 'hace'],
#  ['reverso',
#   'ganas',
#   'constante',
#   'otro',
#   'uno',
#   'no',
#   'al',
#   'solo',
#   'ofrecerte',
#   'tengo',
#   'una',
#   'matarme',
#   'mis',
#   'verso',
#   'nada',
#   'depresion'],
#  ['si', 'no', 'doliera', 'sonreir', 'truco'],
#  ['bien'],
#  ['yo', 'graciosa', 'entiendo', 'delgada', 'bonita'],
#  ['preocupes', 'yo', 'me', 'no', 'tampoco', 'te', 'escogeria'],
#  ['hospital',
#   'me',
#   'mente',
#   'mi',
#   'todo',
#   'si',
#   'escribiera',
#   'pasa',
#   'un',
#   'meterian',
#   'psiquiatrico'],
#  ['demuestra',
#   'palabras',
#   'ahorcado',
#   'del',
#   'equivocadas',
#   'matar',
#   'juego',
#   'podemos',
#   'diciendo',
#   'alguien'],
#  ['siempre',
#   'caperucita',
#   'si',
#   'quien',
#   'lobo',
#   'cuenta',
#   'historia',
#   'sera',
#   'malo'],
#  ['podria',
#   'hacerme',
#   'dejar',
#   'quiza',
#   'era',
#   'unica',
#   'ellos',
#   'sufrir',
#   'tenian',
#   'razon'],
#  ['muerte'],
#  ['tener',
#   'hablar',
#   'me',
#   'tenido',
#   'diferente',
#   'dejas',
#   'entiendo',
#   'si',
#   'simplemente',
#   'asi',
#   'ninguno',
#   'vida',
#   'amiga',
#   'se',
#   'una',
#   'suicida',
#   'haber',
#   'alejas',
#   'te',
#   'desearia'],
#  ['mas', 'valiente', 'ser', 'simplemente', 'feliz', 'bonita', 'desearia'],
#  ['reia',
#   'quedo',
#   'me',
#   'todo',
#   'nina',
#   'no',
#   'le',
#   'temia',
#   'pregunto',
#   'veces',
#   'nada',
#   'donde'],
#  ['saber',
#   'mi',
#   'conocerme',
#   'implica',
#   'no',
#   'nombre',
#   'deja',
#   'juzgarme',
#   'pues'],
#  ['me', 'sufrido', 'ves', 'riendo', 'no', 'sabes'],
#  ['estoy', 'vengo', 'no', 'sabes', 'donde'],
#  ['pasado', 'hecho', 'no', 'oido', 'sabes', 'has'],
#  ['realidad',
#   'dulce',
#   'sabes',
#   'mi',
#   'miedo',
#   'no',
#   'historia',
#   'se',
#   'nombre',
#   'lastimen',
#   'tiene',
#   'solo',
#   'muy',
#   've',
#   'fria'],
#  ['asi', 'no', 'vivir', 'sobrevivir'],
#  ['nosotros',
#   'existen',
#   'dentro',
#   'monstruos',
#   'solo',
#   'ellos',
#   'veces',
#   'fantasmas',
#   'viven'],
#  ['escapo',
#   'sirvo',
#   'bonita',
#   'inteligente',
#   'nada',
#   'divertida',
#   'delgada',
#   'se',
#   'soy',
#   'aun',
#   'me',
#   'mis',
#   'ellos',
#   'problemas',
#   'cortandome',
#   'descubran',
#   'yo',
#   'pasara',
#   'ganan',
#   'no',
#   'cual',
#   'dia'],
#  ['mi',
#   'persona',
#   'frialdad',
#   'una',
#   'soy',
#   'muchas',
#   'veces',
#   'fria',
#   'proteccion'],
#  ['me', 'luego', 'hablarme', 'le', 'importaba', 'dejo', 'dijo', 'nada'],
#  ['hola',
#   'amigo',
#   'ser',
#   'burla',
#   'afiladas',
#   'tu',
#   'suicida',
#   'dano',
#   'querias',
#   'navajas',
#   'contigo',
#   'siempre',
#   'ti',
#   'amiga',
#   'se',
#   'soy',
#   'hacer',
#   'ellas',
#   'estado',
#   'mas',
#   'navaja',
#   'son',
#   'me',
#   'cortada',
#   'nunca',
#   'lenguas',
#   'conseguiste',
#   'querria',
#   'mis',
#   'una',
#   'favor',
#   'amigas',
#   'abandonan',
#   'morire',
#   'broma',
#   'tienen',
#   'quien',
#   'sola',
#   'no',
#   'deja',
#   'te'],
#  ['no', 'nadie', 'necesitas'],
#  ['suficiente', 'tienes', 'tu'],
#  ['muere', 'uno', 'vida', 'solucionada', 'tiene', 'cuando'],
#  ['qu',
#   'fallado',
#   'quieren',
#   'me',
#   'intentado',
#   'diablos',
#   'miles',
#   'suicidarme',
#   'viva',
#   'he',
#   'veces',
#   'todas'],
#  ['mas', 'hacen', 'me', 'solo', 'sufrir'],
#  ['me', 'demonios', 'ser', 'dictan', 'mis', 'soy'],
#  ['mente', 'nuestra', 'propia', 'somos', 'victimas'],
#  ['este',
#   'estar',
#   'mi',
#   'alejada',
#   'mundo',
#   'audifonos',
#   'sola',
#   'mis',
#   'solo',
#   'quiero',
#   'habitacion'],
#  ['cara',
#   'verdadera',
#   'mundo',
#   'su',
#   'ver',
#   'no',
#   'solo',
#   'mostraba',
#   'queria'],
#  ['tus', 'nadie', 'si', 'nota', 'tu', 'dolor', 'errores'],
#  ['cicatrices',
#   'edad',
#   'yo',
#   'cara',
#   'mayoria',
#   'mi',
#   'tienen',
#   'brazos',
#   'chicas',
#   'mis',
#   'bonita',
#   'solo',
#   'tengo'],
#  ['me', 'todo', 'un', 'cansare', 'decir', 'bien', 'dia'],
#  ['ya',
#   'cortes',
#   'adicta',
#   'dificil',
#   'encontrar',
#   'volviste',
#   'comienzas',
#   'cortarte',
#   'entras',
#   'salida',
#   'te',
#   'cuando',
#   'depresion'],
#  ['creen', 'equivocados', 'conocen', 'estan', 'ellos', 'te'],
#  ['saber', 'triste', 'levantarse', 'no', 'quiero', 'mananas', 'sentirse'],
#  ['siempre',
#   'dios',
#   'estar',
#   'vivirla',
#   'todo',
#   'fingir',
#   'dado',
#   'evitar',
#   'tiempo',
#   'llorando',
#   'vida',
#   'fuerte',
#   'tengo',
#   'sabe',
#   'suficientemente',
#   'te',
#   'porque'],
#  ['adolescentes', 'tristes', 'somos', 'felices', 'caras'],
#  ['tenemos', 'esconder'],
#  ['nosotros',
#   'fingimos',
#   'mundo',
#   'oscuro',
#   'todo',
#   'dentro',
#   'no',
#   'queremos',
#   'vea',
#   'bien'],
#  ['podria', 'amar', 'quien', 'chica', 'una', 'suicida'],
#  ['realidad', 'morir', 'crees', 'quieres', 'solo', 'salven', 'te'],
#  ['finges',
#   'siempre',
#   'importo',
#   'vez',
#   'mismo',
#   'todo',
#   'ser',
#   'manera',
#   'perdoname',
#   'otra',
#   'hija',
#   'miedo',
#   'quisiste',
#   'no',
#   'te',
#   'desconfiar',
#   'tu',
#   'pase',
#   'mama'],
#  ['sabes', 'peor'],
#  ['mejorando',
#   'va',
#   'todo',
#   'derrumbar',
#   'vida',
#   'vuelve',
#   'te',
#   'cuando',
#   'sientes',
#   'nada'],
#  ['demas',
#   'saber',
#   'hacen',
#   'me',
#   'mi',
#   'gustaria',
#   'morirme',
#   'un',
#   'al',
#   'solo',
#   'reaccionan',
#   'muerte',
#   'dia'],
#  ['son',
#   'amigos',
#   'puedes',
#   'todo',
#   'tus',
#   'pensamientos',
#   'si',
#   'menos',
#   'suicidas',
#   'no',
#   'escapar',
#   'familia',
#   'enemigos'],
#  ['realidad',
#   'hacen',
#   'olvidaron',
#   'pesadillas',
#   'se',
#   'dijeron',
#   'suenos',
#   'decir',
#   'eran',
#   'tambien'],
#  ['filo',
#   'vez',
#   'ganas',
#   'mi',
#   'y',
#   'otra',
#   'piel',
#   'rozando',
#   'aquel',
#   'sentir',
#   'fino',
#   'cortarme',
#   'regresaron',
#   'dividiendola'],
#  ['demas',
#   'preocupar',
#   'me',
#   'callada',
#   'guste',
#   'estar',
#   'no',
#   'solo',
#   'quiero'],
#  ['despues',
#   'entenderas',
#   'mi',
#   'batallas',
#   'ser',
#   'dias',
#   'vida',
#   'suicida',
#   'lagrimas',
#   'perdidas',
#   'horrible',
#   'terapia',
#   'dijo',
#   'cicatrices',
#   'promesas',
#   'estar',
#   'rotas',
#   'ano',
#   'rotos',
#   'palabras',
#   'son',
#   'me',
#   'corazon',
#   'nunca',
#   'espejo',
#   'frente',
#   'tal',
#   'cara',
#   'vez',
#   'roto',
#   'psiquiatra',
#   'asquerosa',
#   'duerme',
#   'un',
#   'no',
#   'al',
#   'recuerdos',
#   'todos'],
#  ['fragil',
#   'cicatrices',
#   'historias',
#   'cuerpo',
#   'mas',
#   'son',
#   'parezco',
#   'mi',
#   'escritas',
#   'menos',
#   'un',
#   'seria',
#   'estorbo',
#   'soy',
#   'familia',
#   'claro'],
#  ['puedo',
#   'nada',
#   'canso',
#   'salir',
#   'me',
#   'ya',
#   'yo',
#   'mi',
#   'persona',
#   'intentar',
#   'sola',
#   'luchar',
#   'no',
#   'sentir',
#   'dejare',
#   'tambien',
#   'te',
#   'dijo',
#   'adelante'],
#  ['alma',
#   'son',
#   'siempre',
#   'del',
#   'estar',
#   'espejo',
#   'ser',
#   'dicho',
#   'un',
#   'vivo',
#   'mejor',
#   'solo',
#   'veces',
#   'lagrimas',
#   'tambien'],
#  ['suicidas', 'tiempo', 'una', 'vida', 'mata', 'estafa', 'te'],
#  ['tener',
#   'este',
#   'del',
#   'tus',
#   'rara',
#   'entrar',
#   'siento',
#   'cicatrices',
#   'murmuro',
#   'gente',
#   'locos',
#   'luego',
#   'nacer',
#   'he',
#   'ojala',
#   'se',
#   'mueras',
#   'apunala',
#   'preguntan',
#   'me',
#   'espejo',
#   'escenario',
#   'seria',
#   'retiro',
#   'lloramos',
#   'tanto',
#   'desaparecer',
#   'gran',
#   'acostumbrado',
#   'soledad',
#   'ira',
#   'compania',
#   'espalda',
#   'munecas',
#   'no',
#   'al',
#   'mala',
#   'idea',
#   'te'],
#  ['piensa',
#   'amigo',
#   'llevarme',
#   'llorar',
#   'yo',
#   'mi',
#   'vuelvo',
#   'ser',
#   'ves',
#   'derecho',
#   'mejor',
#   'feliz',
#   'al',
#   'distinto',
#   'tengo',
#   'parecer',
#   'felicidad',
#   'pienso',
#   'destino'],
#  ['temprano',
#   'amigo',
#   'novia',
#   'tendra',
#   'tarde',
#   'su',
#   'ti',
#   'juntos',
#   'mejor',
#   'iran',
#   'amiga',
#   'tu',
#   'dejara',
#   'diciendo',
#   'te',
#   'mierdas'],
#  ['cicatrices',
#   'significan',
#   'responder',
#   'munecas',
#   'hijos',
#   'nuestros',
#   'vamos',
#   'nuestras',
#   'les',
#   'cuando',
#   'pregunten'],
#  ['demuestra',
#   'cicatrices',
#   'son',
#   'superficiales',
#   'todo',
#   'no',
#   'se',
#   'sufrimiento',
#   'todas'],
#  ['mas', 'todo', 'pequena', 'era', 'facil'],
#  ['mas',
#   'duelen',
#   'tus',
#   'infiernos',
#   'sonreir',
#   'ahi',
#   'peor',
#   'mientras',
#   'te',
#   'viven',
#   'nada',
#   'donde'],
#  ['sonrisa', 'hermosa', 'tenia', 'una'],
#  ['falsa', 'era', 'brazos', 'sus', 'decian'],
#  ['odiabas', 'no', 'tu', 'recuerdas', 'te'],
#  ['mas',
#   'llanto',
#   'odiarte',
#   'contener',
#   'no',
#   'hicieron',
#   'fuerte',
#   'hay',
#   'ellos',
#   'dolor',
#   'te'],
#  ['me',
#   'estoy',
#   'lluvia',
#   'estar',
#   'gusta',
#   'nadie',
#   'llorando',
#   'asi',
#   'sabe',
#   'porque'],
#  ['llorar',
#   'mirada',
#   'morir',
#   'respirar',
#   'tengas',
#   'lucifer',
#   'sonrie',
#   'un',
#   'aunque',
#   'no',
#   'quiero',
#   'angel',
#   'sufrir',
#   'dejar'],
#  ['ciego',
#   'va',
#   'amar',
#   'persona',
#   'amor',
#   'especial',
#   'no',
#   'completamente',
#   'solo',
#   'vida',
#   'necesitas',
#   'cambiar',
#   'te',
#   'hace'],
#  ['voy', 'me', 'morir'],
#  ['sola', 'fea', 'muerta', 'gorda'],
#  ['rodeada', 'me', 'estoy', 'gente', 'totalmente', 'sola', 'siento'],
#  ['cuerpo',
#   'mano',
#   'pocos',
#   'huesos',
#   'rollos',
#   'sentir',
#   'tu',
#   'horrible',
#   'marcados',
#   'pasar',
#   'grasa'],
#  ['son', 'cuadraditos', 'canelones', 'forma', 'jodan', 'mis', 'no'],
#  ['tener',
#   'me',
#   'tuve',
#   'amo',
#   'grune',
#   'sensacion',
#   'sentir',
#   'mala',
#   'idea',
#   'pansa',
#   'hambre'],
#  ['saber',
#   'este',
#   'mismos',
#   'estara',
#   'espero',
#   'ser',
#   'nadie',
#   'mejor',
#   'vaca',
#   'verme',
#   'cuerpo',
#   'siempre',
#   'deprime',
#   'ano',
#   'feliz',
#   'soy',
#   'pasaron',
#   'colegio',
#   'yendo',
#   'diciendo',
#   'viven',
#   'me',
#   'nosotros',
#   'conmigo',
#   'espejo',
#   'nunca',
#   'perdon',
#   'querernos',
#   'anos',
#   'ya',
#   'tantos',
#   'sea',
#   'enseno',
#   'al'],
#  ['mas',
#   'pasado',
#   'son',
#   'lastiman',
#   'junto',
#   'momentos',
#   'personas',
#   'te',
#   'has',
#   'mejores'],
#  ['mi', 'casa', 'quiero', 'quedarme'],
#  ['gusta', 'navidad', 'no', 'me'],
#  ['hoy', 'no', 'hacer', 'pienso', 'nada'],
#  ['odio', 'navidad'],
#  ['si',
#   'ser',
#   'mejor',
#   'vida',
#   'etapa',
#   'vea',
#   'verdad',
#   'bien',
#   'menos',
#   'poco',
#   'feliz',
#   'se',
#   'adolescencia',
#   'estoy',
#   'supuestamente',
#   'persona',
#   'necesito',
#   'kilos',
#   'creo',
#   'mal',
#   'otra',
#   'un',
#   'no',
#   'diez'],
#  ['mas',
#   'calor',
#   'llego',
#   'me',
#   'mi',
#   'estar',
#   'literalmente',
#   'todo',
#   'ganas',
#   'trabajar',
#   'flaca',
#   'asi',
#   'le',
#   'igual',
#   'falta',
#   'cintura',
#   'tengo',
#   'quita',
#   'bien'],
#  ['gorda', 'estoy'],
#  ['yo', 'soy'],
#  ['ya',
#   'cuerpo',
#   'mi',
#   'ahora',
#   'digan',
#   'vacaciones',
#   'asco',
#   'un',
#   'no',
#   'feo',
#   'se',
#   'seanmen',
#   'enfermarse',
#   'sinceras'],
#  ['mostrar',
#   'unas',
#   'cara',
#   'llego',
#   'fotos',
#   'me',
#   'estoy',
#   'mi',
#   'dirian',
#   'si',
#   'mias',
#   'no',
#   'gorda'],
#  ['me', 'esto', 'ayudarian', 'necesito', 'verdad'],
#  ['me',
#   'vez',
#   'mi',
#   'gustaria',
#   'creo',
#   'nunca',
#   'llegaria',
#   'una',
#   'gustara',
#   'todas',
#   'eso',
#   'cuesta'],
#  ['me', 'amar', 'mi', 'aprender', 'puedo'],
#  ['mas',
#   'fallado',
#   'me',
#   'vez',
#   'seguido',
#   'persona',
#   'si',
#   'veces',
#   'cada',
#   'siento',
#   'soy',
#   'personas',
#   'cambian'],
#  ['di', 'mi', 'mejor', 'no', 'supiste', 'te', 'valorar'],
#  ['mas', 'dormir', 'nunca', 'no', 'despertar', 'decearia'],
#  ['realmente', 'somos', 'aparentamos', 'ocultar'],
#  ['quedo', 'me', 'siempre', 'gorda', 'marcada'],
#  ['perderia',
#   'mas',
#   'me',
#   'final',
#   'dijiste',
#   'promesa',
#   'esperaba',
#   'nunca',
#   'otra',
#   'pasara',
#   'al',
#   'rota',
#   'te'],
#  ['perdon', 'ser', 'desastre', 'un', 'soy'],
#  ['mas',
#   'me',
#   'anterior',
#   'si',
#   'cada',
#   'digo',
#   'necesito',
#   'creerias',
#   'te',
#   'dia'],
#  ['esperaste', 'fuera', 'perdon', 'ser', 'no'],
#  ['me', 'mente', 'matando', 'mi', 'lentamente'],
#  ['importo',
#   'me',
#   'jode',
#   'todo',
#   'si',
#   'dibujes',
#   'contrario',
#   'cuando',
#   'queres',
#   'no',
#   'te',
#   'hablas'],
#  ['mil',
#   'hizo',
#   'construyete',
#   'persona',
#   'ahora',
#   'luego',
#   'tenemos',
#   'pedazos',
#   'todos',
#   'dijo'],
#  ['mas',
#   'tener',
#   'mirar',
#   'destroza',
#   'no',
#   'sonreir',
#   'hay',
#   'te',
#   'doloroso',
#   'nada'],
#  ['infierno',
#   'me',
#   'yo',
#   'demonios',
#   'oscuridad',
#   'su',
#   'mis',
#   'enamore',
#   'eramos',
#   'perfecto'],
#  ['soy', 'insegura', 'porque'],
#  ['mas', 'ya', 'me', 'seguir', 'cada', 'no', 'paso', 'puedo', 'cuesta'],
#  ['estoy', 'mi', 'demasiado', 'vida', 'pienso', 'bien'],
#  ['odio', 'estomago', 'dormir', 'irme', 'lleno'],
#  ['falsa',
#   'gente',
#   'manera',
#   'otra',
#   'forma',
#   'encuentra',
#   'vida',
#   'entrar',
#   'una',
#   'tu'],
#  ['hueco',
#   'me',
#   'llevar',
#   'pueda',
#   'demasiado',
#   'suelo',
#   'tiempo',
#   'un',
#   'pensando',
#   'casa',
#   'paso'],
#  ['hierren', 'mas', 'palabras', 'arma', 'un', 'una', 'apunalada'],
#  ['quedo', 'hizo', 'ira', 'marca', 'no', 'facil', 'se', 'dejo', 'doler'],
#  ['arma', 'jamas', 'sufra', 'no', 'peor', 'suicida', 'sufrir'],
#  ['ganas', 'no', 'fingir', 'tengo'],
#  ['me', 'hay', 'veces', 'deprimo', 'nada'],
#  ['cicatrices',
#   'tocar',
#   'dejas',
#   'sanan',
#   'curar',
#   'abrirlas',
#   'terminan',
#   'se',
#   'cuando'],
#  ['mas', 'notar', 'va', 'nadie', 'no', 'existire', 'algunos', 'dia'],
#  ['mas', 'aguanto', 'no'],
#  ['no', 'desaparecer', 'veo', 'hora'],
#  ['vez', 'va', 'todo', 'terminar', 'una', 'se', 'cuando'],
#  ['este', 'rien', 'desastre', 'se', 'todos'],
#  ['importo', 'si', 'nadie', 'no', 'le', 'vida'],
#  ['mi', 'mejor', 'todos', 'estan'],
#  ['si',
#   'volver',
#   'incluso',
#   'siempre',
#   'gordita',
#   'muera',
#   'sera',
#   'necesitando',
#   'mas',
#   'me',
#   'odiare',
#   'todo',
#   'tiempo',
#   'facil',
#   'recuerdo',
#   'broma',
#   'peso',
#   'era',
#   'un',
#   'kg',
#   'al',
#   'palabra',
#   'estaria'],
#  ['ya', 'no', 'hay', 'decir', 'nada'],
#  ['pasado', 'mierda', 'vez', 'peor', 'sentirte', 'alguna', 'te'],
#  ['cuerpo',
#   'me',
#   'enojo',
#   'nunca',
#   'mi',
#   'esto',
#   'huesos',
#   'ver',
#   'obsesion',
#   'maldita',
#   'peor',
#   'digas',
#   'sobresalir',
#   'porque'],
#  ['nunca', 'si', 'gorda', 'verme', 'dejar', 'puedo'],
#  ['saber',
#   'deprimentes',
#   'me',
#   'volvieron',
#   'color',
#   'esos',
#   'pone',
#   'mal',
#   'ir',
#   'era',
#   'pensabas',
#   'rosas',
#   'al',
#   'vida',
#   'lunes',
#   'colegio',
#   'tengo',
#   'domingos',
#   'enserio'],
#  ['odio',
#   'tener',
#   'estar',
#   'conmigo',
#   'miles',
#   'nadie',
#   'sola',
#   'no',
#   'cosas',
#   'fisicamente',
#   'hacer'],
#  ['lentamente', 'muero', 'poco'],
#  ['ya', 'llorar', 'noches', 'me', 'costumbre', 'todas'],
#  ['mas', 'real', 'llanto', 'existir', 'puede', 'sentimiento'],
#  ['saber',
#   'siempre',
#   'persona',
#   'ahora',
#   'banca',
#   'mucho',
#   'no',
#   'comida',
#   'quiero',
#   'todas',
#   'extrano',
#   'te',
#   'tenes',
#   'alguien',
#   'nada'],
#  ['mi', 'horrible', 'cuerpo'],
#  ['navaja', 'brazo', 'mi', 'ganas', 'una', 'escribir', 'historia', 'agarrar'],
#  ['infierno',
#   'temprano',
#   'dejaste',
#   'me',
#   'caer',
#   'tarde',
#   'volvemos',
#   'demonio',
#   'un',
#   'sola',
#   'convertiste',
#   'todos'],
#  ['me', 'hoy', 'voy', 'nomas', 'tomar', 'dedicar', 'agua'],
#  ['cerda', 'dios', 'amor', 'deja', 'comer'],
#  ['cuerpo', 'yo', 'veo', 'vez', 'mi', 'asquerosidad', 'cada'],
#  ['mismos',
#   'nosotros',
#   'tropezarnos',
#   'ser',
#   'derecho',
#   'tenemos',
#   'felices',
#   'todos',
#   'dejar'],
#  ['unico',
#   'realmente',
#   'mi',
#   'oculto',
#   'amo',
#   'cuenta',
#   'aqui',
#   'digo',
#   'identidad',
#   'pienso',
#   'ocultar',
#   'nada'],
#  ['yo',
#   'me',
#   'mi',
#   'mis',
#   'no',
#   'hay',
#   'banco',
#   'tampoco',
#   'veces',
#   'amigas',
#   'culpa'],
#  ['saltar',
#   'cuando',
#   'falsas',
#   'morir',
#   'poco',
#   'abrazo',
#   'comidas',
#   'evitar',
#   'mas',
#   'nunca',
#   'sonrisas',
#   'repetir',
#   'personas',
#   'completa',
#   'sentiste',
#   'llorar',
#   'vez',
#   'ultima',
#   'un',
#   'fue',
#   'te',
#   'alguien'],
#  ['mil', 'llevar', 'demonios', 'un', 'sonrisa', 'tu', 'cabeza', 'ngel'],
#  ['hola', 'haces'],
#  ['cosas', 'mal', 'todas'],
#  ['cobardes', 'suicidio'],
#  ['si'],
#  ['cobardes', 'veamos', 'intentalo', 'si'],
#  ['mas', 'error', 'un', 'solo', 'soy'],
#  ['mundo', 'dime', 'quien', 'pedazos', 'se', 'buscas', 'te', 'cuando', 'cae'],
#  ['este', 'hecho', 'mejor', 'ano', 'has'],
#  ['detras',
#   'oculta',
#   'tristeza',
#   'momento',
#   'gran',
#   'mal',
#   'sonrisa',
#   'una',
#   'se',
#   'toda'],
#  ['mas', 'fotos', 'persona', 'ser', 'fea', 'puedo'],
#  ['este', 'va', 'quien', 'desastre', 'querer'],
#  ['amor', 'aceptamos', 'creemos', 'merecer'],
#  ['nadie', 'era', 'un', 'se', 'resolver', 'gasto', 'misterio'],
#  ['persona',
#   'correspondida',
#   'prometeme',
#   'no',
#   'una',
#   'solo',
#   'te',
#   'enamoraste'],
#  ['vas', 'manana', 'despertar'],
#  ['me', 'todo', 'era', 'decia', 'un', 'princesa', 'cuento', 'porque'],
#  ['soy', 'desastre', 'amor', 'un'],
#  ['me', 'creerte', 'quieres', 'no', 'capaz', 'soy', 'digas', 'porque'],
#  ['exactamente',
#   'mas',
#   'nada',
#   'momento',
#   'me',
#   'fue',
#   'algun',
#   'arrepiento',
#   'dicho',
#   'cada',
#   'he',
#   'no',
#   'vida',
#   'dia',
#   'senti',
#   'porque',
#   'eso',
#   'dificil'],
#  ['siempre', 'mierda'],
#  ['ya',
#   'existe',
#   'alto',
#   'me',
#   'esto',
#   'si',
#   'rindes',
#   'fracaso',
#   'solo',
#   'rendi',
#   'soy',
#   'te',
#   'cuando',
#   'eso',
#   'hace'],
#  ['vida'],
#  ['dolor', 'descripcion'],
#  ['cumplir', 'vez', 'pudieron', 'un', 'suyo', 'alguna', 'sueno'],
#  ['tiempo', 'necesito', 'desaparecer', 'un'],
#  ['ser', 'menos', 'un', 'no', 'porque', 'linda', 'puedo', 'dia'],
#  ['llorado', 'vez', 'odiarte', 'alguna', 'has'],
#  ['nada', 'siempre', 'eso', 'dicen'],
#  ['infierno', 'este', 'siempre', 'unico', 'pido', 'sea', 'no', 'vida', 'eso'],
#  ['su', 'un', 'rato', 'apagar', 'encendio', 'vida', 'musica'],
#  ['tanto',
#   'mi',
#   'corazon',
#   'cuando',
#   'sabia',
#   'estabas',
#   'mintiendo',
#   'dolor',
#   'te',
#   'crei',
#   'confunde'],
#  ['cambio',
#   'ya',
#   'amaba',
#   'cambie',
#   'yo',
#   'mas',
#   'gente',
#   'mi',
#   'miro',
#   'ano',
#   'no',
#   'vida',
#   'atras',
#   'puedo',
#   'creer'],
#  ['ya',
#   'me',
#   'segunda',
#   'opcion',
#   'tu',
#   'empiezo',
#   'sere',
#   'hora',
#   'soy',
#   'deprimir',
#   'entendi'],
#  ['terminaremos', 'algun', 'sea', 'muertos', 'todos', 'dia'],
#  ['vez', 'soltarla', 'una', 'se', 'abraza', 'muy', 'muerte', 'dificil'],
#  ['pasado',
#   'ya',
#   'va',
#   'matarse',
#   'jamas',
#   'borrar',
#   'un',
#   'no',
#   'se',
#   'suicida',
#   'puede',
#   'intentar'],
#  ['suicida', 'era', 'homicida'],
#  ['hacian', 'perfecta', 'dos', 'pareja'],
#  ['pasado',
#   'exceso',
#   'igual',
#   'haber',
#   'importaba',
#   'gracias',
#   'te',
#   'fingido',
#   'depresion'],
#  ['futuro', 'exceso', 'ansiedad'],
#  ['comer', 'vomitar'],
#  ['tener',
#   'onda',
#   'sexual',
#   'primera',
#   'vez',
#   'tienen',
#   'puta',
#   'conoces',
#   'uno',
#   'ano',
#   'no',
#   'tu',
#   'casi',
#   'hace'],
#  ['me', 'espejo', 'mire', 'al', 'agrade', 'sera', 'vea', 'cuando', 'dia'],
#  ['son', 'mayoria', 'mis', 'amistades', 'temporales'],
#  ['tener',
#   'onda',
#   'sexual',
#   'primera',
#   'vez',
#   'tienen',
#   'puta',
#   'conoces',
#   'uno',
#   'ano',
#   'no',
#   'tu',
#   'casi',
#   'hace'],
#  ['ya',
#   'me',
#   'yo',
#   'ltimamente',
#   'te',
#   'feliz',
#   'no',
#   'enserio',
#   'crei',
#   'hace'],
#  ['me', 'equivoque'],
#  ['tal',
#   'demuestro',
#   'vez',
#   'si',
#   'menos',
#   'forma',
#   'te',
#   'no',
#   'hermosa',
#   'quiero',
#   'soy',
#   'linda',
#   'cualquier',
#   'mucho'],
#  ['importe', 'mostrarme', 'turno', 'demostre', 'quise', 'enserio', 'tu', 'te'],
#  ['me',
#   'yo',
#   'ser',
#   'al',
#   'igual',
#   'solo',
#   'iba',
#   'diferente',
#   'uso',
#   'todos',
#   'crei'],
#  ['buenita', 'distinta', 'ahora', 'esto', 'antes', 'soy', 'eras', 'listo'],
#  ['gusta', 'mi', 'si', 'no', 'vida', 'se', 'soy', 'van', 'les', 'listo'],
#  ['damelo',
#   'messi',
#   'me',
#   'gustaria',
#   'tantos',
#   'tantas',
#   'momentos',
#   'repetir',
#   'perder',
#   'hay',
#   'vos',
#   'veces',
#   'prefiero',
#   'perderte'],
#  ['cuerpo',
#   'regalame',
#   'quien',
#   'no',
#   'beba',
#   'hermosa',
#   'soy',
#   'tu',
#   'decir',
#   'puedo',
#   'sos'],
#  ['era', 'un', 'ano', 'no', 'soy', 'atras', 'hace'],
#  ['heterosexual',
#   'atraida',
#   'me',
#   'confundida',
#   'chicas',
#   'gustos',
#   'mis',
#   'siento',
#   'soy',
#   'muy'],
#  ['cuerpo', 'pedir', 'un', 'asi', 'tanto'],
#  ['fuera', 'bonita', 'si'],
#  ['me', 'estoy', 'vez', 'suelo', 'pie', 'muriendo'],
#  ['del',
#   'bien',
#   'salio',
#   'afecta',
#   'mundo',
#   'soy',
#   'paso',
#   'mas',
#   'todavia',
#   'me',
#   'persona',
#   'todo',
#   'una',
#   'minima',
#   'ya',
#   'lloro',
#   'insegura',
#   'sea',
#   'sensible',
#   'mitad',
#   'no',
#   'cualquier'],
#  ['siempre',
#   'mundo',
#   'encontras',
#   'uno',
#   'al',
#   'boludos',
#   'lleno',
#   'te',
#   'dia'],
#  ['solucion', 'dormir', 'animo', 'mis', 'tengo', 'problemas', 'todos', 'piso'],
#  ['realidad', 'me', 'escapo', 'un', 'rato', 'feo'],
#  ['estupido'],
#  ['nada', 'bueno'],
#  ['mierda'],
#  ['inutil'],
#  ['saber',
#   'tenia',
#   'siempre',
#   'final',
#   'yo',
#   'vez',
#   'mi',
#   'nadie',
#   'otra',
#   'decepcionante',
#   'al',
#   'no',
#   'se',
#   'van',
#   'subconsciente',
#   'importante',
#   'todos',
#   'razon'],
#  ['despues',
#   'carta',
#   'mi',
#   'ser',
#   'sonrisa',
#   'sabor',
#   'sigo',
#   'pretendo',
#   'feliz',
#   'subir',
#   'me',
#   'gustaria',
#   'todo',
#   'dentro',
#   'siendo',
#   'acido',
#   'igual',
#   'una',
#   'debil',
#   'fuerte',
#   'rostro',
#   'mientras',
#   'senti',
#   'ese',
#   'recibir',
#   'nuevamente',
#   'garganta'],
#  ['cambiarias', 'ti'],
#  ['parte',
#   'pudiera',
#   'mi',
#   'todo',
#   'si',
#   'volveria',
#   'nacer',
#   'felicidad',
#   'lejos',
#   'cambiaria'],
#  ['si',
#   'ilusionado',
#   'moleste',
#   'sentimientos',
#   'cuando',
#   'duelen',
#   'dificil',
#   'medio',
#   'le',
#   'quiero',
#   'se',
#   'desilusionaron',
#   'veces',
#   'mas',
#   'palabras',
#   'decirle',
#   'duele',
#   'mis',
#   'ya',
#   'desgarraron',
#   'hubieron',
#   'tantas',
#   'recuerdos',
#   'te'],
#  ['deseada',
#   'lasti',
#   'tenia',
#   'me',
#   'promesa',
#   'rompes',
#   'mi',
#   'abuela',
#   'ahora',
#   'fui',
#   'nuevamente',
#   'no',
#   'una',
#   'madre',
#   'dicen',
#   'tengo',
#   'primera',
#   'fue',
#   'cuando'],
#  ['ya', 'rompes', 'persona', 'destrozada', 'poco', 'una', 'falta', 'tambien'],
#  ['tristeza',
#   'lloraba',
#   'no',
#   'sonreir',
#   'dolia',
#   'felicidad',
#   'extrano',
#   'dolor',
#   'cuando'],
#  ['extrano', 'feliz', 'ser'],
#  ['tus', 'otro', 'necesito', 'abrazos'],
#  ['escuchar', 'soledad', 'lluvia', 'bueno'],
#  ['saber',
#   'mi',
#   'acune',
#   'acostumbre',
#   'cuando',
#   'gotas',
#   'https',
#   'unica',
#   'ver',
#   'quiero',
#   'soy',
#   'beber',
#   'mas',
#   'me',
#   'estoy',
#   'co',
#   'visto',
#   'aprendi',
#   'cosita',
#   'ventanas',
#   'rostro',
#   'linda',
#   'agua',
#   'fw',
#   'llorar',
#   'okljzmr',
#   'soledad',
#   'sola',
#   'no',
#   'nacio',
#   'golpean',
#   'silencio'],
#  ['fumar', 'quiero'],
#  ['mi', 'arda', 'piel', 'quiero'],
#  ['cortar', 'cuerpo', 'quiero', 'mi'],
#  ['hacerme', 'quiero', 'dano'],
#  ['mas', 'ya', 'no', 'soporto'],
#  ['final', 'triste', 'chiste', 'un', 'vida'],
#  ['mierda'],
#  ['hacer', 'debo', 'decir'],
#  ['saber',
#   'mirada',
#   'si',
#   'repente',
#   'bien',
#   'cuando',
#   'porque',
#   'hospital',
#   'quedo',
#   'callada',
#   'esperanzas',
#   'abrazan',
#   'me',
#   'gustaria',
#   'pasase',
#   'ir',
#   'digan',
#   'un',
#   'conocen',
#   'al',
#   'no',
#   'hay',
#   'dia'],
#  ['soy', 'reemplazable'],
#  ['me',
#   'siempre',
#   'almohada',
#   'posible',
#   'mi',
#   'soledad',
#   'otra',
#   'ves',
#   'abrace',
#   'preguntaba',
#   'llore',
#   'no',
#   'tanta',
#   'porque'],
#  ['mas',
#   'son',
#   'gente',
#   'realiza',
#   'animales',
#   'maltrato',
#   'general',
#   'seres',
#   'puros',
#   'mascotas'],
#  ['fcdadntbo',
#   'este',
#   'hice',
#   'gente',
#   'https',
#   'mundo',
#   'acabo',
#   'se',
#   'son',
#   'instagram',
#   'me',
#   'mierda',
#   'co',
#   'aun',
#   'di',
#   'corazon',
#   'latir',
#   'madufx',
#   'dejado',
#   'incen',
#   'puede',
#   'romper',
#   'mal',
#   'encontrar',
#   'un',
#   'no',
#   'cuenta',
#   'peor'],
#  ['todo', 'esto', 'terminar', 'solo', 'quiero'],
#  ['coraje', 'me', 'falta'],
#  ['llorar', 'ganas', 'simplemente', 'no', 'tengo', 'lagrimas', 'salen'],
#  ['acumulada',
#   'oxigeno',
#   'unico',
#   'posible',
#   'hago',
#   'todo',
#   'mal',
#   'robar',
#   'tiempo',
#   'solo',
#   'soy',
#   'basura',
#   'sentirse'],
#  ['molesto',
#   'mi',
#   'pgd',
#   'del',
#   'nadie',
#   'volver',
#   'otro',
#   'hiciste',
#   'amo',
#   'vida',
#   'sentir',
#   'horrible',
#   'dolor',
#   'bien',
#   'muerte',
#   'amigos',
#   'https',
#   'estar',
#   'pasa',
#   'se',
#   'madre',
#   'viejos',
#   'sabe',
#   'canciones',
#   'hace',
#   'demas',
#   'me',
#   'estoy',
#   'co',
#   'corazon',
#   'gustaria',
#   'realmente',
#   'vojlhz',
#   'necesito',
#   'una',
#   'vez',
#   'ese',
#   'orgullosa',
#   'acariciar',
#   'un',
#   'no',
#   'busco',
#   'solo',
#   'dijera',
#   'hay',
#   'suenan',
#   'te',
#   'dia'],
#  ['alma',
#   'rompen',
#   'siempre',
#   'algun',
#   'soledad',
#   'alejan',
#   'tenemos',
#   'tipo',
#   'momentos',
#   'se',
#   'deseo',
#   'personas',
#   'sentimiento',
#   'porque'],
#  ['son', 'aun', 'sonrie', 'ojos', 'sus', 'tristes', 'feliz', 'cuando'],
#  ['felicidad',
#   'otros',
#   'mundo',
#   'fondo',
#   'uno',
#   'un',
#   'vivimos',
#   'muy',
#   'debilidad',
#   'deseo',
#   'entretenimiento',
#   'donde'],
#  ['cicatrices',
#   'maldito',
#   'caer',
#   'me',
#   'miro',
#   'volvere',
#   'un',
#   'fracaso',
#   'mis',
#   'solo',
#   'vida',
#   'soy',
#   'pregunto',
#   'cuando'],
#  ['cada',
#   'tzy',
#   'cuando',
#   'alma',
#   'piensa',
#   'https',
#   'menos',
#   'soy',
#   'dicen',
#   'qu',
#   'co',
#   'rcqtpo',
#   'duele',
#   'estan',
#   'personas',
#   'les',
#   'frente',
#   'duela',
#   'vez',
#   'un',
#   'no',
#   'sienten',
#   'al',
#   'solo',
#   'deja',
#   'alguien',
#   'dia'],
#  ['deseas'],
#  ['este', 'morir', 'creo', 'sea', 'mejor', 'feliz', 'ano', 'eso'],
#  ['abrazo', 'necesito', 'un'],
#  ['cy',
#   'comienzan',
#   'ser',
#   'olvidando',
#   'santy',
#   'rt',
#   'eso',
#   'depresion',
#   'dormir',
#   'https',
#   'invito',
#   'zuniga',
#   'estoy',
#   'co',
#   'pensamientos',
#   'wpcr',
#   'todo',
#   'hambre',
#   'parte',
#   'gritos',
#   'ansiedad',
#   'nuevamente',
#   'placentero',
#   'no',
#   'go',
#   'hay',
#   'destruyendome',
#   'te'],
#  ['aturdida', 'me', 'siento'],
#  ['no', 'se'],
#  ['alma',
#   'me',
#   'mente',
#   'yo',
#   'llora',
#   'mi',
#   'vuelvo',
#   'ves',
#   'cada',
#   'duele',
#   'casa',
#   'tambien'],
#  ['gusta', 'no', 'soledad', 'me'],
#  ['mi',
#   'abrace',
#   'ves',
#   'mochilas',
#   'canse',
#   'mejor',
#   'porque',
#   'siempre',
#   'libre',
#   'sere',
#   'hecho',
#   'me',
#   'existencia',
#   'preguntaba',
#   'llore',
#   'tengo',
#   'sacar',
#   'tanto',
#   'ya',
#   'odio',
#   'almohada',
#   'ahora',
#   'otra',
#   'compania',
#   'espalda',
#   'no',
#   'solo',
#   'fue'],
#  ['mas', 'sol', 'y', 'cada', 'le', 'siento', 'dia'],
#  ['decir',
#   'estoy',
#   'quien',
#   'orgullosa',
#   'simplemente',
#   'hoy',
#   'un',
#   'no',
#   'lindo',
#   'soy',
#   'fue',
#   'puedo',
#   'dia'],
#  ['cayo', 'importa', 'no', 'le', 'una', 'se', 'lagrima'],
#  ['vemos',
#   'llego',
#   'apagan',
#   'realmente',
#   'importa',
#   'no',
#   'se',
#   'veces',
#   'casa',
#   'cuando'],
#  ['todo', 'fingia', 'siempre', 'tiempo'],
#  ['todo', 'fingia', 'bien', 'estaba'],
#  ['ya', 'me', 'sentirme', 'acostumbre', 'basura'],
#  ['sigo', 'me', 'preguntando'],
#  ['aborto', 'no', 'me', 'mierda'],
#  ['repruebo',
#   'estudio',
#   'respire',
#   'si',
#   'molesta',
#   'no',
#   'le',
#   'se',
#   'tanto',
#   'pasando'],
#  ['voy', 'distraida', 'vida'],
#  ['no', 'logro', 'hacer', 'bien', 'nada'],
#  ['mas',
#   'recordar',
#   'roba',
#   'oxigeno',
#   'mi',
#   'mundo',
#   'objeto',
#   'ocupa',
#   'un',
#   'conozco',
#   'solo',
#   'soy',
#   'lugar',
#   'familia',
#   'masoquista'],
#  ['soy', 'reemplazable'],
#  ['suicidarse',
#   'estoy',
#   'manera',
#   'otra',
#   'ojos',
#   'sonreir',
#   'diciendo',
#   'lagrimas',
#   'llenos',
#   'bien'],
#  ['estar', 'soledad', 'no', 'solo', 'vacio'],
#  ['mas', 'llorar', 'cuanto', 'tendre'],
#  ['duele', 'y'],
#  ['quieren',
#   'realmente',
#   'tus',
#   'dificil',
#   'ser',
#   'sea',
#   'quien',
#   'padres',
#   'seas',
#   'hace'],
#  ['trae', 'perfume', 'tambien', 'recuerdos'],
#  ['palabras',
#   'ahora',
#   'calme',
#   'otra',
#   'un',
#   'abrazo',
#   'necesito',
#   'se',
#   'dicen',
#   'personas',
#   'cuando'],
#  ['mi', 'tuve', 'soltar', 'agarrarme', 'muy', 'fuerte'],
#  ['despues',
#   'mi',
#   'ves',
#   'cada',
#   'siento',
#   'rapido',
#   'cuerpo',
#   'cayendo',
#   'espinas',
#   'se',
#   'hacer',
#   'ocultar',
#   'daga',
#   'mas',
#   'construi',
#   'muro',
#   'corazon',
#   'tiempo',
#   'acostumbro',
#   'tanto',
#   'un',
#   'no',
#   'dia'],
#  ['da',
#   'ves',
#   'termino',
#   'porque',
#   'decepcion',
#   'siempre',
#   'va',
#   'asco',
#   'cambiare',
#   'aun',
#   'me',
#   'espejo',
#   'todo',
#   'mirarme',
#   'asi',
#   'tal',
#   'hago',
#   'creo',
#   'mal',
#   'al',
#   'peor'],
#  ['me', 'gustaria', 'digan', 'peliculas', 'escucho', 'muchas', 'veces'],
#  ['demas', 'gusta', 'dejas', 'nadie', 'no', 'lastimar', 'te', 'destruyan'],
#  ['todo',
#   'pasa',
#   'tenemos',
#   'humanos',
#   'no',
#   'costumbre',
#   'decir',
#   'seres',
#   'cuando',
#   'nada'],
#  ['desastre', 'soy', 'un'],
#  ['ridicula',
#   'inutil',
#   'mente',
#   'izquierda',
#   'mi',
#   'vales',
#   'asco',
#   'un',
#   'fea',
#   'no',
#   'gorda',
#   'doy',
#   'cero',
#   'nada',
#   'sos'],
#  ['buscar',
#   'extranar',
#   'querer',
#   'cada',
#   'sincero',
#   'dejamos',
#   'abrazo',
#   'quiero',
#   'se',
#   'fisicamente',
#   'hablar',
#   'aun',
#   'me',
#   'estoy',
#   'mental',
#   'poner',
#   'necesito',
#   'tanto',
#   'puedo',
#   'leer',
#   'aca',
#   'ese',
#   'un',
#   'cansada',
#   'no',
#   'pie',
#   'solo',
#   'escribir',
#   'te',
#   'alguien',
#   'dia'],
#  ['saber',
#   'tanto',
#   'encajas',
#   'pense',
#   'nunca',
#   'gritos',
#   'no',
#   'duro',
#   'silenciosos',
#   'sonreir',
#   'doleria',
#   'locura'],
#  ['mas', 'necesita', 'queda', 'uno', 'solo', 'se', 'cuando', 'alguien'],
#  ['explicaciones', 'gente', 'pensar', 'tiende', 'quieres', 'no', 'des'],
#  ['mi', 'si', 'ti', 'llegado', 'llore', 'he', 'limite', 'creeme', 'frente'],
#  ['me', 'yo', 'alejo', 'asi', 'sobro', 'siento', 'soy', 'cuando'],
#  ['despues',
#   'tal',
#   'tanto',
#   'vez',
#   'psicologo',
#   'todo',
#   'verte',
#   'tiempo',
#   'feliz',
#   'no',
#   'vida',
#   'sonrieras',
#   'daria',
#   'todos',
#   'dijo'],
#  ['son', 'monstruos', 'amigable', 'solo', 'apariencia', 'aterradores'],
#  ['pelota', 'gente', 'si', 'hoy', 'idiota', 'no', 'les', 'des', 'dia'],
#  ['tener',
#   'quiebra',
#   'si',
#   'bronca',
#   'piensan',
#   'dias',
#   'siento',
#   'porque',
#   'comentario',
#   'trata',
#   'abrazo',
#   'se',
#   'me',
#   'divertido',
#   'voz',
#   'necesito',
#   'razon',
#   'esto',
#   'un',
#   'sola',
#   'solo',
#   'hay',
#   'lleno',
#   'fue'],
#  ['esos', 'dias', 'uno', 'hoy'],
#  ['llorar',
#   'estoy',
#   'nudo',
#   'vez',
#   'mi',
#   'instalo',
#   'ganas',
#   'otra',
#   'un',
#   'hondo',
#   'al',
#   'igual',
#   'digo',
#   'se',
#   'garganta',
#   'respiro',
#   'bien'],
#  ['no', 'llores'],
#  ['no', 'te', 'cortes'],
#  ['no', 'lastimes', 'te'],
#  ['navaja', 'suelta'],
#  ['tal', 'vez', 'puedes', 'ganar', 'batalla', 'no', 'facil'],
#  ['despedidas', 'aquellas', 'son', 'peores', 'tuvieron', 'explicacion', 'no'],
#  ['ya',
#   'me',
#   'veo',
#   'da',
#   'espejo',
#   'simple',
#   'asco',
#   'reconozco',
#   'al',
#   'no',
#   'verme'],
#  ['duermen',
#   'nadie',
#   'volver',
#   'cancion',
#   'escuchan',
#   'cuando',
#   'porque',
#   'su',
#   'detuvo',
#   'se',
#   'dicen',
#   'angeles',
#   'cardiaco',
#   'son',
#   'aplaudio',
#   'todo',
#   'hogar',
#   'tiempo',
#   'musica',
#   'mucho',
#   'realidad',
#   'quieren',
#   'tansimple',
#   'ultima',
#   'suicidas',
#   'desean',
#   'interpreto',
#   'escapar',
#   'monitor'],
#  ['mas', 'vez', 'aplaudieron', 'estar', 'desee', 'una', 'muerta', 'todos'],
#  ['trate', 'me', 'buscar', 'triste', 'mal', 'traia'],
#  ['era'],
#  ['vida', 'solo'],
#  ['quieren',
#   'mente',
#   'haces',
#   'mi',
#   'callame',
#   'constante',
#   'quien',
#   'pelea',
#   'sea',
#   'una',
#   'soy',
#   'callate'],
#  ['infierno',
#   'este',
#   'acumulada',
#   'nudo',
#   'mi',
#   'si',
#   'puta',
#   'volver',
#   'ser',
#   'necesita',
#   'boca',
#   'perderme',
#   'triste',
#   'dar',
#   'le',
#   'quiero',
#   'suceder',
#   'mata',
#   'vivir',
#   'merece',
#   'vacio',
#   'hace',
#   'mas',
#   'ibas',
#   'me',
#   'scotch',
#   'pense',
#   'tristeza',
#   'persona',
#   'nunca',
#   'todo',
#   'significa',
#   'ci',
#   'una',
#   'cruel',
#   'cinta',
#   'puede',
#   'fria',
#   'desaparecer',
#   'humano',
#   'ya',
#   'taparte',
#   'yo',
#   'rabia',
#   'teniendolo',
#   'hija',
#   'traigo',
#   'un',
#   'no',
#   'garganta',
#   'cielo',
#   'te',
#   'sentirse'],
#  ['este', 'sirva', 'algun', 'espero', 'dolor', 'dia'],
#  ['llora', 'su', 'nadie', 've', 'le', 'casa', 'cuando'],
#  ['demas',
#   'enteraras',
#   'cara',
#   'siempre',
#   'nunca',
#   'eso',
#   'sonrie',
#   'te',
#   'porque'],
#  ['mas',
#   'creen',
#   'son',
#   'mismos',
#   'sangran',
#   'conocerse',
#   'heridas',
#   'si',
#   'curar',
#   'dolorosas',
#   'deprimidas',
#   'no',
#   'personas',
#   'bien',
#   'cuesta'],
#  ['personalidad',
#   'su',
#   'ven',
#   'no',
#   'muralla',
#   'una',
#   'llamada',
#   'hay',
#   'ellos',
#   'saben',
#   'depresion'],
#  ['bailas',
#   'triste',
#   'letra',
#   'si',
#   'comprendes',
#   'cancion',
#   'una',
#   'alegre',
#   'te',
#   'sientes'],
#  ['mi', 'espectacular', 'vida', 'sido', 'mirando', 'atras'],
#  ['mas', 'disfrutado', 'deberia', 'haber'],
#  ['pena',
#   'llorar',
#   'compasion',
#   'buen',
#   'hombro',
#   'curar',
#   'un',
#   'al',
#   'dosis',
#   'una',
#   'se',
#   'puede'],
#  ['penumbra',
#   'llora',
#   'siempre',
#   'desconsoladamente',
#   'persona',
#   'su',
#   'riendo',
#   'mejor',
#   'hablando',
#   'habitacion'],
#  ['triste',
#   'esos',
#   'aparente',
#   'momentos',
#   'decaido',
#   'ninguna',
#   'te',
#   'sientes',
#   'razon'],
#  ['realidad',
#   'nosotros',
#   'esfuma',
#   'sera',
#   'adentramos',
#   'si',
#   'cuestionamos',
#   'una',
#   'se',
#   'nuestro',
#   'futuro',
#   'deprimimos',
#   'introspeccion'],
#  ['primer',
#   'mas',
#   'levantarte',
#   'despertarte',
#   'cada',
#   'valentia',
#   'acto',
#   'debes',
#   'cama',
#   'hacer',
#   'manana',
#   'nada'],
#  ['posee',
#   'si',
#   'quien',
#   'deprimido',
#   'llaves',
#   'una',
#   'prisionero',
#   'cual',
#   'carcel',
#   'libertad',
#   'te',
#   'encuentras',
#   'tambien'],
#  ['pena', 'alegria'],
#  ['extrana', 'mezcla', 'evoca', 'depresion'],
#  ['sinonimo', 'gente', 'estar', 'no', 'rodeado', 'sentirse'],
#  ['mas',
#   'tener',
#   'hablar',
#   'abiertamente',
#   'llegar',
#   'tus',
#   'mero',
#   'nadie',
#   'puedes',
#   'secretos',
#   'soledad',
#   'quien',
#   'confiar',
#   'ni',
#   'no',
#   'solo',
#   'sentirte',
#   'hecho'],
#  ['este',
#   'tenga',
#   'pueda',
#   'entender',
#   'un',
#   'solo',
#   'vida',
#   'futuro',
#   'deseo',
#   'sufrimiento',
#   'objetivo'],
#  ['yo', 'me', 'siempre', 'he', 'has', 'ahi', 'necesitado', 'cuando', 'estado'],
#  ['mismo', 'mi', 'ahora', 'necesito', 'hagas'],
#  ['fuesen',
#   'batallas',
#   'si',
#   'subidas',
#   'ganar',
#   'victoria',
#   'no',
#   'ni',
#   'moral',
#   'una',
#   'guerra',
#   'obtendria',
#   'depresion'],
#  ['me', 'pesadilla', 'despierto', 'duermo', 'cada', 'una', 'cuando', 'dia'],
#  ['sino',
#   'abierto',
#   'aconseje',
#   'mente',
#   'corazon',
#   'estamos',
#   'logica',
#   'un',
#   'escuche',
#   'tristes',
#   'no',
#   'ocasiones',
#   'una',
#   'sentido',
#   'necesitamos',
#   'cuando'],
#  ['del',
#   'si',
#   'dieron',
#   'eterna',
#   'nada',
#   'depresion',
#   'alma',
#   'suena',
#   'profundo',
#   'mas',
#   'todo',
#   'golpe',
#   'tenerlo',
#   'perderlo',
#   'deprimente',
#   'un',
#   'al',
#   'siguiente',
#   'huella',
#   'te',
#   'dia'],
#  ['odio',
#   'me',
#   'su',
#   'compania',
#   'forzado',
#   'siento',
#   'pesar',
#   'convivir',
#   'depresion'],
#  ['nadar',
#   'ahogarse',
#   'ayuda',
#   'nadie',
#   'oceano',
#   'medio',
#   'un',
#   'acuda',
#   'tu',
#   'depresion'],
#  ['sino',
#   'grado',
#   'pobreza',
#   'dinero',
#   'tienes',
#   'soledad',
#   'no',
#   'sensacion',
#   'se',
#   'tu',
#   'mide'],
#  ['nace', 'heridas', 'no', 'nuestras', 'cuando', 'curamos', 'depresion'],
#  ['mujer',
#   'intrinseco',
#   'hombre',
#   'todo',
#   'nadie',
#   'oculto',
#   'estan',
#   'conoce',
#   'un',
#   'tristes',
#   'lleva',
#   'frios',
#   'tildamos',
#   'veces',
#   'les',
#   'dolor',
#   'cuando',
#   'solamente'],
#  ['verdaderos',
#   'son',
#   'este',
#   'das',
#   'quienes',
#   'amigos',
#   'tus',
#   'momentos',
#   'cuenta',
#   'te'],
#  ['estoy', 'fuera', 'dentro', 'sea', 'acero', 'puede', 'cristal', 'hecho'],
#  ['cansado',
#   'mi',
#   'placeres',
#   'otro',
#   'mejor',
#   'sudor',
#   'aqui',
#   'viene',
#   'cuerpo',
#   'va',
#   'queda',
#   'causa',
#   'medio',
#   'postor',
#   'gemidos',
#   'mas',
#   'suicidio',
#   'tristeza',
#   'dinero',
#   'pasion',
#   'desdicha',
#   'fingida',
#   'sentido',
#   'continuar',
#   'vendidos',
#   'asquerosa',
#   'aletargado',
#   'rutina',
#   'no',
#   'al',
#   'solo',
#   'cual',
#   'dia'],
#  ['mi',
#   'vi',
#   'vida',
#   'rapido',
#   'razones',
#   'venir',
#   'llevaron',
#   'su',
#   'pertenece',
#   'envuelta',
#   'rapidas',
#   'victima',
#   'doi',
#   'mas',
#   'eligio',
#   'me',
#   'estoy',
#   'recompensas',
#   'sus',
#   'una',
#   'fuertes',
#   'cruel',
#   'alguna',
#   'vez',
#   'ahora',
#   'creo',
#   'ir',
#   'elegir',
#   'no',
#   'cuenta',
#   'tentada',
#   'fue'],
#  ['buscar',
#   'mi',
#   'cliente',
#   'mejor',
#   'tendida',
#   'aqui',
#   'cama',
#   'alma',
#   'cuerpo',
#   'seguir',
#   'espera',
#   'queda',
#   'su',
#   'se',
#   'deseo',
#   'pues',
#   'me',
#   'una',
#   'ultimo',
#   'ya',
#   'perdido',
#   'vacia',
#   'ido'],
#  ['agonia',
#   'del',
#   'instantes',
#   'cliente',
#   'volver',
#   'ser',
#   'aquel',
#   'ni',
#   'amo',
#   'cuando',
#   'borroso',
#   'cuerpo',
#   'hombre',
#   'amar',
#   'supe',
#   'le',
#   'antes',
#   'casi',
#   'ofrecer',
#   'podia',
#   'silenciosa',
#   'proxima',
#   'me',
#   'minutos',
#   'persona',
#   'signifique',
#   'una',
#   'recuerdo',
#   'tengo',
#   'alguna',
#   'quedan',
#   'yo',
#   'vez',
#   'un',
#   'penas',
#   'no',
#   'solo',
#   'proximo',
#   'fue',
#   'alguien'],
#  ['ducha',
#   'este',
#   'mi',
#   'del',
#   'ves',
#   'ire',
#   'despertare',
#   'entrare',
#   'dolor',
#   'impregnado',
#   'cuerpo',
#   'luego',
#   'menos',
#   'poco',
#   'se',
#   'sacara',
#   'costumbre',
#   'sera',
#   'veces',
#   'contando',
#   'pues',
#   'esperar',
#   'preparar',
#   'llevara',
#   'mas',
#   'me',
#   'aquella',
#   'minutos',
#   'todo',
#   'velas',
#   'callendo',
#   'nunca',
#   'hoy',
#   'decision',
#   'instante',
#   'nauseabundo',
#   'sueno',
#   'agua',
#   'prendere',
#   'ya',
#   'continuar',
#   'unas',
#   'seran',
#   'olor',
#   'tarde',
#   'arrepiento',
#   'ahora',
#   'era',
#   'otras',
#   'ira',
#   'un',
#   'no',
#   'distinto',
#   'durmiendo',
#   'lentamente',
#   'alguien'],
#  ['decidire',
#   'pueda',
#   'volvera',
#   'mi',
#   'otro',
#   'irse',
#   'cama',
#   'descansar',
#   'fin',
#   'alma',
#   'cuerpo',
#   'pertenece',
#   'mia',
#   'mio',
#   'quiero',
#   'sera',
#   'me',
#   'final',
#   'minutos',
#   'todo',
#   'hare',
#   'asi',
#   'una',
#   'instante',
#   'recostare',
#   'donde',
#   'ya',
#   'yo',
#   'ningun',
#   'vez',
#   'encontrar',
#   'un',
#   'no',
#   'solo',
#   'arreglo',
#   'ajeno'],
#  ['calor',
#   'agonia',
#   'mi',
#   'espero',
#   'cliente',
#   'si',
#   'ni',
#   'enoje',
#   'verdad',
#   'cuando',
#   'cuerpo',
#   'frio',
#   'se',
#   'habra',
#   'mas',
#   'pasion',
#   'fingida',
#   'soporto',
#   'ya',
#   'notar',
#   'terminara',
#   'vez',
#   'no',
#   'al'],
#  ['infiel',
#   'siempre',
#   'espejo',
#   'defectos',
#   'un',
#   'cada',
#   'tendre',
#   'todos',
#   'refleja',
#   'dia'],
#  ['ya',
#   'me',
#   'horrenda',
#   'han',
#   'amar',
#   'tantas',
#   'dicho',
#   'un',
#   'adefesio',
#   'soy',
#   'veces',
#   'fea',
#   'imposibilitado'],
#  ['mi',
#   'rodea',
#   'cuando',
#   'acercaria',
#   'siempre',
#   'delgadas',
#   'lindas',
#   'amor',
#   'se',
#   'mas',
#   'enamorada',
#   'tierno',
#   'nunca',
#   'asi',
#   'chicas',
#   'una',
#   'imposible',
#   'chico',
#   'yo',
#   'jamas',
#   'guapo',
#   'un',
#   'gorda',
#   'estaria',
#   'cerca'],
#  ['maldito',
#   'bolsa',
#   'cada',
#   'ni',
#   'comida',
#   'boca',
#   'grasa',
#   'su',
#   'medio',
#   'kilo',
#   'soy',
#   'demuestra',
#   'contar',
#   'cerda',
#   'me',
#   'caloria',
#   'espejo',
#   'poner',
#   'una',
#   'maldita',
#   'mientras',
#   'puede',
#   'bocado',
#   'suplicio',
#   'un',
#   'no',
#   'dia'],
#  ['horribles',
#   'cada',
#   'ojos',
#   'espacio',
#   'porque',
#   'formas',
#   'queda',
#   'pasa',
#   'brazos',
#   'ver',
#   'respuestas',
#   'ellas',
#   'sacas',
#   'mas',
#   'son',
#   'me',
#   'encuentro',
#   'dios',
#   'mias',
#   'dejeme',
#   'mis',
#   'ya',
#   'cortes',
#   'piernas',
#   'otras',
#   'delatan',
#   'hermosas',
#   'no',
#   'profundos',
#   'dia'],
#  ['terrible',
#   'este',
#   'mi',
#   'cada',
#   'miedo',
#   'absolutamente',
#   'padres',
#   'hice',
#   'notado',
#   'pase',
#   'su',
#   'manto',
#   'defraudarlos',
#   'terminar',
#   'mia',
#   'cubre',
#   'quiero',
#   'se',
#   'soy',
#   'intensa',
#   'hace',
#   'aun',
#   'me',
#   'hacerla',
#   'idea',
#   'ustedes',
#   'asi',
#   'una',
#   'tengo',
#   'calvario',
#   'intencion',
#   'inservible',
#   'mucho',
#   'yo',
#   'cambios',
#   'han',
#   'tienen',
#   'asquerosa',
#   'ahora',
#   'hija',
#   'no',
#   'mala',
#   'imperfecta',
#   'peor',
#   'tomarla',
#   'fue',
#   'tambien'],
#  ['ves',
#   'calorias',
#   'cada',
#   'comida',
#   'cama',
#   'brazos',
#   'dejare',
#   'se',
#   'sera',
#   'desangren',
#   'me',
#   'espejo',
#   'hoy',
#   'comia',
#   'mis',
#   'rompere',
#   'recostare',
#   'jamas',
#   'ultima',
#   'notas',
#   'libreta'],
#  ['dije', 'jamas', 'tantas', 'veces', 'hice'],
#  ['sera', 'distinto', 'adios', 'hoy'],
#  ['pudo',
#   'mas',
#   'asumir',
#   'queria',
#   'vi',
#   'un',
#   'hoy',
#   'no',
#   'sido',
#   'haber',
#   'fue',
#   'lamentablemente',
#   'te',
#   'dia'],
#  ['cansado',
#   'dejaste',
#   'este',
#   'carta',
#   'mails',
#   'mi',
#   'ni',
#   'tiene',
#   'cartas',
#   'recibias',
#   'quieres',
#   'ver',
#   'llamadas',
#   'se',
#   'sera',
#   'hace',
#   'mas',
#   'me',
#   'sonido',
#   'constantes',
#   'telefono',
#   'voz',
#   'tiempo',
#   'insistente',
#   'olvidaste',
#   'mis',
#   'puedes',
#   'ultima',
#   'al',
#   'no',
#   'te'],
#  ['fuiste',
#   'divertias',
#   'dejaste',
#   'mi',
#   'seras',
#   'tus',
#   'mejor',
#   'vida',
#   'sepas',
#   'cuando',
#   'siempre',
#   'hombre',
#   'amigos',
#   'ver',
#   'quiero',
#   'ame',
#   'escondidas',
#   'mas',
#   'me',
#   'salia',
#   'doliera',
#   'espiarte',
#   'al',
#   'te',
#   'aunque'],
#  ['despues',
#   'sonar',
#   'llanto',
#   'dejaste',
#   'ducha',
#   'hacias',
#   'mi',
#   'buscaba',
#   'esperando',
#   'ves',
#   'cada',
#   'amo',
#   'algunas',
#   'cerca',
#   'tu',
#   'lagrimas',
#   'sentirte',
#   'entonces',
#   'sed',
#   'foto',
#   'derramaba',
#   'aquellas',
#   'quedaba',
#   'ponia',
#   'imaginaba',
#   'dormir',
#   'abrazaba',
#   'ti',
#   'veia',
#   'amor',
#   'noche',
#   'antes',
#   'camisa',
#   'lamentablemente',
#   'mas',
#   'me',
#   'besabas',
#   'calmara',
#   'pasion',
#   'asi',
#   'una',
#   'fuerte',
#   'lindo',
#   'noches',
#   'recuerdo',
#   'estabas',
#   'tanto',
#   'alguna',
#   'venias',
#   'manana',
#   'besaba',
#   'closet',
#   'tuvimos',
#   'era',
#   'dormida',
#   'perfume',
#   'usaba',
#   'no',
#   'pie',
#   'solo',
#   'siguiente',
#   'te',
#   'silencio'],
#  ['saber',
#   'entenderas',
#   'respirar',
#   'mi',
#   'nadie',
#   'estuviera',
#   'tu',
#   'familia',
#   'dolor',
#   'contigo',
#   'formar',
#   'ti',
#   'juntos',
#   'mio',
#   'vivir',
#   'ame',
#   'deseaba',
#   'queria',
#   'podria',
#   'mas',
#   'me',
#   'fueras',
#   'nunca',
#   'fuera',
#   'tiempo',
#   'una',
#   'hijos',
#   'senti',
#   'yo',
#   'al',
#   'no',
#   'solo',
#   'te',
#   'darte'],
#  ['mi',
#   'ser',
#   'amarte',
#   'amo',
#   'vida',
#   'tu',
#   'dolor',
#   'seas',
#   'podre',
#   'porque',
#   'eternamente',
#   'demasiado',
#   'feliz',
#   'se',
#   'me',
#   'verte',
#   'amas',
#   'asi',
#   'tendre',
#   'puedo',
#   'ya',
#   'yo',
#   'jamas',
#   'acabar',
#   'otra',
#   'vuelva',
#   'vaya',
#   'no',
#   'al',
#   'lado',
#   'te'],
#  ['mi',
#   'si',
#   'ves',
#   'ser',
#   'bien',
#   'papa',
#   'dificil',
#   'pretendo',
#   'dije',
#   'cumplo',
#   'breve',
#   'dejas',
#   'adios',
#   'he',
#   'se',
#   'hecho',
#   'me',
#   'estoy',
#   'queridos',
#   'escribirlo',
#   'deben',
#   'decision',
#   'tristes',
#   'mato',
# ...
#   'cuando',
#   'dia'],
#  ['hola', 'hannah'],
#  ['hola'],
#  ['vaya'],
#  ['serio', 'humor', 'mal', 'tenemos', 'un', 'hoy', 'caso'],
#  ['monet', 'del', 'despues', 'colegio'],
#  ['wow'],
#  ['mas', 'me', 'conoces', 'pensaba'],
#  ['iremos', 'y', 'claro'],
#  ['aburridas', 'reimos', 'pasamos', 'clases', 'ambas'],
#  ['monet',
#   'momento',
#   'me',
#   'dijiste',
#   'admirador',
#   'oye',
#   'hannah',
#   'luego',
#   'tienes',
#   'un'],
#  [],
#  ['donde'],
#  ['detras', 'ti'],
#  ['vuelta', 'miramos', 'se', 'dio'],
#  ['ti', 'no', 'estaba', 'jess', 'mirando', 'viste', 'te'],
#  ['manera', 'solo', 'una', 'hay', 'averiguarlo'],
#  ['ese',
#   'oye',
#   'dos',
#   'y',
#   'mirabas',
#   'estaba',
#   'sentado',
#   'cual',
#   'fuimos',
#   'chico',
#   'donde'],
#  ['jess'],
#  ['ambas', 'reimos'],
#  ['hannah', 'soy'],
#  ['hannah', 'baker'],
#  ['jessica', 'yo'],
#  ['jessica', 'davis'],
#  ['alex'],
#  ['standall', 'alex'],
#  ['hablar', 'todo', 'empezamos', 'tarde'],
#  ['dos', 'y', 'ser', 'asi', 'tres', 'pasamos'],
#  ['amigos', 'semanas', 'varias', 'fuimos', 'mejores'],
#  ['monet', 'alguno', 'tenia', 'vez', 'bamos', 'cada', 'un', 'problema'],
#  ['mi', 'al', 'vida', 'carajo', 'recuerdas'],
#  ['me', 'yo', 'amigos', 'sentia', 'tres', 'feliz', 'mis', 'muy'],
#  ['fin', 'tenia', 'unos'],
#  ['empezaron', 'excluir', 'me', 'del', 'ustedes', 'grupo'],
#  ['habia', 'descubrir', 'ustedes', 'no', 'lograba'],
#  ['monet', 'empezo', 'ir', 'alex', 'dejar'],
#  ['te', 'siempre', 'veia', 'colegio'],
#  ['pasaba', 'descubri', 'dia', 'un'],
#  ['porque', 'vi'],
#  ['besandose'],
#  ['me',
#   'absoluto',
#   'ustedes',
#   'molestaba',
#   'no',
#   'estuvieran',
#   'saliendo',
#   'eso'],
#  ['me', 'molesto', 'si', 'no', 'dijeran'],
#  ['amigos', 'eramos', 'no'],
#  ['despues', 'decidiste', 'volver', 'una', 'hablarme', 'semana'],
#  ['hola', 'hannah'],
#  ['hola', 'jess'],
#  ['tal'],
#  ['bien'],
#  ['monet', 'despues', 'del', 'ir', 'podemos', 'colegio'],
#  ['claro'],
#  ['vemos', 'alli'],
#  ['mi', 'alegro', 'se'],
#  ['monet', 'despues', 'ir', 'tiempo', 'volveriamos', 'mucho'],
#  ['me', 'esperando', 'alli', 'una', 'llegue', 'estabas', 'cuando', 'mesa'],
#  ['hola', 'jess'],
#  ['hola', 'hannah'],
#  ['sientate'],
#  ['quiero', 'hablarte'],
#  ['dime', 'claro'],
#  ['gusta', 'te', 'alex'],
#  [],
#  ['loca', 'jess'],
#  ['alex', 'me', 'gustar', 'va'],
#  ['dices', 'porque'],
#  ['ti', 'pues', 'miralo'],
#  ['sacaste', 'y', 'maldita', 'lista'],
#  ['escrito', 'habia', 'alex'],
#  ['tenia', 'yo', 'decia', 'trasero', 'mejor'],
#  ['quede', 'bastante', 'odio', 'me', 'mirando'],
#  ['hannah', 'esto', 'me', 'dices'],
#  ['estupida', 'una', 'jess', 'lista'],
#  ['me', 'gustaria', 'crees', 'alex', 'porque', 'eso'],
#  ['hannah', 'no', 'se'],
#  ['me', 'no', 'diciendo', 'puedo', 'creer'],
#  ['jessica', 'amigas', 'somos'],
#  ['amigos', 'no', 'traicionan', 'se'],
#  ['son', 'amigos', 'fieles', 'no', 'todos'],
#  ['jessica', 'haz', 'quieras'],
#  ['te', 'solo', 'dire'],
#  ['disfrutalo'],
#  ['cierto', 'eso', 'porque', 'haras'],
#  ['eso', 'porque', 'hacen', 'zorras'],
#  ['mierda', 'vete'],
#  ['paraste', 'abofeteaste', 'me', 'te'],
#  ['hannah', 'adios'],
#  ['acabo', 'se'],
#  ['empece', 'llorar'],
#  ['amiga', 'habia', 'otra', 'perdido'],
#  ['eso', 'dime', 'porque', 'hiciste'],
#  ['amistad', 'nuestra', 'mi', 'desconfiaste', 'porque'],
#  ['dia', 'conocimos', 'empezare'],
#  ['monet',
#   'momento',
#   'me',
#   'admirador',
#   'estar',
#   'oye',
#   'hannah',
#   'tienes',
#   'un',
#   'recuerdo',
#   'jessica',
#   'dijo'],
#  [],
#  ['donde'],
#  ['detras', 'ti'],
#  ['vuelta', 'diste', 'miramos', 'te'],
#  ['ti', 'no', 'estaba', 'jess', 'mirando', 'viste', 'te'],
#  ['manera', 'solo', 'una', 'hay', 'averiguarlo'],
#  ['y', 'sentado', 'fuimos', 'estabas', 'donde'],
#  ['oye', 'dos', 'cual', 'mirabas'],
#  ['jess'],
#  ['hannah', 'soy', 'ambas', 'reimos'],
#  ['hannah', 'baker'],
#  ['jessica', 'yo'],
#  ['jessica', 'davis'],
#  ['alex'],
#  ['standall', 'alex'],
#  ['hablar', 'todo', 'empezamos', 'tarde'],
#  ['dos', 'y', 'ser', 'asi', 'tres', 'pasamos'],
#  ['amigos', 'semanas', 'varias', 'fuimos', 'mejores'],
#  ['monet', 'alguno', 'tenia', 'vez', 'bamos', 'cada', 'un', 'problema'],
#  ['mi', 'al', 'vida', 'carajo', 'recuerdas'],
#  ['escolar', 'empezaste', 'juntarte', 'luego', 'tu', 'equipo'],
#  ['aun', 'mismo', 'era', 'hablabas', 'no'],
#  ['conmigo', 'tiempo', 'pasabas', 'no', 'jess', 'casi'],
#  ['dia', 'ese'],
#  ['me', 'peores', 'uno', 'tocado', 'fue', 'vivir'],
#  ['culpa', 'tu'],
#  ['habras', 'hecho'],
#  ['principio', 'les', 'contare'],
#  ['yo', 'siempre', 'normalmente', 'al', 'jess', 'colegio', 'llegamos'],
#  ['su', 'fue', 'clase'],
#  ['amigos',
#   'tus',
#   'hoja',
#   'papel',
#   'vi',
#   'una',
#   'escribiendo',
#   'te',
#   'entonces',
#   'nuevos'],
#  ['di', 'no', 'le', 'importancia'],
#  ['despues', 'horas', 'dos'],
#  ['reian', 'me', 'mi', 'hoja', 'vi', 'miraban', 'una', 'clase', 'todos'],
#  ['mi', 'escrito', 'acaso', 'habias'],
#  ['no', 'podia', 'saberlo'],
#  ['nunca',
#   'hoja',
#   'lamente',
#   'quise',
#   'amiga',
#   'haber',
#   'sido',
#   'tu',
#   'recibi',
#   'cuando'],
#  ['pensando', 'estabas'],
#  ['serio', 'tenia', 'yo', 'trasero', 'escribiste', 'mejor'],
#  ['odie', 'te', 'eso'],
#  ['cuanto', 'sufri', 'no', 'tu', 'sabes', 'eso'],
#  ['observada', 'senti', 'me'],
#  ['me', 'hostigaron'],
#  ['realmente', 'amigo', 'mi', 'eras'],
#  ['empezar', 'antes', 'quiero', 'una', 'hacerte', 'pregunta'],
#  ['vez', 'observado', 'sentido', 'alguna', 'te', 'has'],
#  ['asi', 'fue', 'me', 'senti'],
#  ['observada'],
#  ['yo', 'mi', 'todo', 'empieza', 'volvia', 'noche', 'una', 'casa'],
#  ['yo', 'me', 'dormir', 'era', 'rara', 'hora', 'senti'],
#  ['me', 'si', 'estuvieran', 'observando', 'senti'],
#  ['estoy',
#   'si',
#   'flash',
#   'era',
#   'un',
#   'ver',
#   'segura',
#   'no',
#   'camara',
#   'pequeno',
#   'podia',
#   'aunque',
#   'eso'],
#  ['era', 'ver', 'no', 'una', 'llegue', 'humana', 'sombra', 'cualquier'],
#  ['courtney', 'escuela', 'conoci', 'crimsen', 'al', 'siguiente', 'dia'],
#  ['todo', 'le', 'conte'],
#  ['hablarlo', 'alguien', 'queria'],
#  ['hola', 'courtney', 'soy'],
#  ['crimsen', 'courtney'],
#  ['hannah'],
#  ['hannah', 'baker'],
#  ['conocerte', 'gusto', 'hannah'],
#  ['me', 'dormir', 'rara', 'muy', 'hora', 'senti', 'sabes', 'anoche'],
#  ['ocurrio'],
#  ['paso'],
#  ['me', 'si', 'estuvieran', 'observando', 'senti'],
#  ['estoy',
#   'si',
#   'flash',
#   'era',
#   'un',
#   'ver',
#   'segura',
#   'no',
#   'camara',
#   'pequeno',
#   'podia',
#   'aunque',
#   'eso'],
#  ['mi',
#   'era',
#   'estuvo',
#   'casa',
#   'ver',
#   'no',
#   'una',
#   'alguien',
#   'llegue',
#   'humana',
#   'sombra',
#   'cualquier',
#   'anoche'],
#  ['ayudare',
#   'armar',
#   'acosador',
#   'raro',
#   'atrapar',
#   'bueno',
#   'poder',
#   'al',
#   'una',
#   'trampa',
#   'mira',
#   'te'],
#  ['me', 'dices'],
#  ['gusta', 'me', 'idea'],
#  ['noche'],
#  ['vale'],
#  ['perfecto'],
#  ['salio', 'todo', 'control', 'y', 'noche', 'se'],
#  ['momento', 'llego', 'empezare', 'courney', 'casa'],
#  ['hannah', 'hey'],
#  [],
#  ['bien'],
#  ['han', 'pasa', 'mis', 'se', 'cenar', 'padres', 'ido', 'adelante'],
#  ['esto', 'flash', 'pasa', 'ves', 'asi', 'hora', 'te', 'sombra', 'sientes'],
#  ['doce', 'esto', 'pasa', 'noche', 'una', 'manana'],
#  ['aun',
#   'tenemos',
#   'tiempo',
#   'marca',
#   'haremos',
#   'sobra',
#   'mientras',
#   'tanto',
#   'reloj'],
#  ['recorde', 'solas', 'estabamos'],
#  ['todo', 'sentirnos', 'podriamos', 'hacer', 'quisieramos', 'culpables'],
#  ['nadie', 'se', 'enteraria'],
#  ['yo', 'menos', 'pensaba', 'al', 'eso'],
#  ['uhm'],
#  ['pondremos', 'diversion', 'esto', 'poco', 'un'],
#  ['me', 'dices'],
#  ['hannah', 'serio'],
#  ['whisky'],
#  ['loca'],
#  ['pensando'],
#  ['courtney', 'trago', 'un', 'solo', 'vamos', 'sera'],
#  ['acuerdo'],
#  ['solo', 'uno'],
#  ['acosador', 'atrapar', 'tenemos', 'tu', 'porque'],
#  ['ya', 'si', 'se'],
#  ['trago', 'solo', 'fueron', 'un'],
#  ['mas', 'tal', 'vez', 'o', 'eso'],
#  ['mas',
#   'encontrabamos',
#   'mi',
#   'un',
#   'haciendo',
#   'poco',
#   'tomado',
#   'tonteras',
#   'habitacion',
#   'habiamos'],
#  ['borrachas', 'muy', 'estabamos'],
#  ['sacarte', 'reto', 'hannah', 'te', 'brasier'],
#  [],
#  ['debajo', 'tranquila', 'blusa'],
#  ['listo'],
#  ['sacarte', 'yo', 'reto', 'ahora', 'ti', 'blusa', 'te'],
#  ['listo'],
#  ['me', 'reto', 'ahora', 'beses', 'te'],
#  ['courtney'],
#  ['no'],
#  ['hannah', 'vamos'],
#  ['un', 'solo', 'tonto', 'reto'],
#  ['va'],
#  ['despues',
#   'courtney',
#   'ese',
#   'realmente',
#   'si',
#   'besarme',
#   'asi',
#   'le',
#   'beso',
#   'llamar',
#   'se',
#   'acerco',
#   'comenzo',
#   'puedo'],
#  ['yo', 'solo', 'segui'],
#  ['mala', 'idea'],
#  ['mi', 'completo', 'olvidamos', 'acosador'],
#  ['nosotras', 'flash', 'y', 'un', 'senti'],
#  ['si'],
#  ['una', 'nosotras', 'foto'],
#  ['besandonos'],
#  ['quite', 'courtney', 'linterna', 'encima', 'mio', 'afuera', 'apunte'],
#  ['estabas', 'ahi', 'tu'],
#  ['tyler'],
#  ['alli', 'haces'],
#  ['acaso', 'espiabas'],
#  ['momento', 'ese', 'y', 'saliste', 'corriendo'],
#  ['seguia', 'aun', 'cama', 'courtney'],
#  ['alterada', 'estaba'],
#  ['hannah'],
#  ['yo'],
#  ['deberia', 'irme'],
#  ['esto', 'siento'],
#  ['error', 'fue', 'un'],
#  ['no', 'hecho', 'debi', 'haberlo'],
#  ['no', 'courtney', 'espera'],
#  ['fue', 'y', 'se', 'corriendo'],
#  ['hablar', 'sucedido', 'tarde', 'fui', 'tu', 'siguiente', 'casa'],
#  ['puerta', 'llame', 'tu'],
#  ['abriste', 'tu'],
#  ['hola', 'hannah', 'tyler'],
#  ['favor', 'pedirte', 'puedo', 'un'],
#  ['si', 'dime'],
#  ['muestres', 'nadie', 'no', 'le', 'foto'],
#  ['bien'],
#  ['hare', 'no'],
#  ['gracias'],
#  ['no', 'nada'],
#  ['tal', 'vez', 'oye', 'hannah', 'pensaba'],
#  ['no', 'se'],
#  ['salir', 'dices', 'podriamos'],
#  [],
#  ['tyler', 'loco'],
#  ['me', 'haces', 'verguenza', 'quieres', 'pasar', 'contigo', 'salga'],
#  ['adios'],
#  ['asi', 'me', 'y', 'fui'],
#  ['pasado', 'habia', 'no', 'podia', 'creer'],
#  ['ya', 'escuela', 'sabia', 'al', 'siguiente', 'foto', 'toda', 'dia'],
#  ['dime', 'eso', 'hiciste'],
#  ['venia',
#   'momento',
#   'courtney',
#   'haciami',
#   'vi',
#   'un',
#   'llorando',
#   'estaba',
#   'corriendo'],
#  ['courtney'],
#  ['ocurre'],
#  ['bien'],
#  ['enteras', 'aun', 'te', 'no'],
#  ['hablar', 'paran', 'todos', 'no', 'saben', 'eso', 'foto'],
#  [],
#  ['posible'],
#  ['maldito', 'tyler'],
#  ['ya', 'amigas', 'hannah', 'creo', 'seamos', 'mejor', 'no', 'sabes'],
#  ['sospechar', 'comenzar', 'podrian'],
#  ['courtney', 'nosotras', 'no', 'somos', 'nota', 'se'],
#  ['ademas', 'borrachas', 'estabamos'],
#  ['haciendo', 'sabiamos', 'no', 'estabamos'],
#  ['hannah', 'no', 'siento', 'adios'],
#  ['no', 'me', 'busques'],
#  ['comence', 'llorar'],
#  ['primer', 'mi', 'alli', 'amiga', 'iba', 'se'],
#  ['fue', 'se', 'corriendo'],
#  ['arruinaste', 'tyler', 'amistad', 'nuestra'],
#  ['hicieras', 'me', 'acaso', 'malo', 'hice', 'te', 'eso'],
#  ['empezar', 'antes', 'quiero', 'una', 'hacerte', 'pregunta'],
#  ['lado', 'vez', 'han', 'tonto', 'solo', 'dejado', 'alguna', 'te', 'paso'],
#  ['asi', 'fue', 'me', 'senti'],
#  ['excluida'],
#  ['dejaste', 'me', 'solo', 'lado', 'paso'],
#  ['dia', 'conocimos', 'empezare'],
#  ['teniamos', 'un', 'examen', 'clase'],
#  ['pasado', 'me', 'anterior', 'habia', 'y', 'noche', 'te', 'conte'],
#  ['hablarlo', 'alguien', 'queria'],
#  ['hola', 'courtney', 'soy'],
#  ['crimsen', 'courtney'],
#  ['hannah'],
#  ['hannah', 'baker'],
#  ['conocerte', 'gusto', 'hannah'],
#  ['me', 'dormir', 'rara', 'muy', 'hora', 'senti', 'sabes', 'anoche'],
#  ['ocurrio'],
#  ['paso'],
#  ['me', 'si', 'estuvieran', 'observando', 'senti'],
#  ['estoy',
#   'si',
#   'flash',
#   'era',
#   'un',
#   'ver',
#   'segura',
#   'no',
#   'camara',
#   'pequeno',
#   'podia',
#   'aunque',
#   'eso'],
#  ['mi',
#   'era',
#   'estuvo',
#   'casa',
#   'ver',
#   'no',
#   'una',
#   'alguien',
#   'llegue',
#   'humana',
#   'sombra',
#   'cualquier',
#   'anoche'],
#  ['ayudare',
#   'armar',
#   'acosador',
#   'raro',
#   'atrapar',
#   'bueno',
#   'poder',
#   'al',
#   'una',
#   'trampa',
#   'mira',
#   'te'],
#  ['me', 'dices'],
#  ['gusta', 'me', 'idea'],
#  ['noche'],
#  ['vale'],
#  ['perfecto'],
#  ['salio', 'todo', 'control', 'y', 'noche', 'se'],
#  ['momento', 'casa', 'llegaste', 'empezare'],
#  ['hannah', 'hey'],
#  [],
#  ['bien'],
#  ['han', 'pasa', 'mis', 'se', 'cenar', 'padres', 'ido', 'adelante'],
#  ['esto', 'flash', 'pasa', 'ves', 'asi', 'hora', 'te', 'sombra', 'sientes'],
#  ['doce', 'esto', 'pasa', 'noche', 'una', 'manana'],
#  ['aun',
#   'tenemos',
#   'tiempo',
#   'marca',
#   'haremos',
#   'sobra',
#   'mientras',
#   'tanto',
#   'reloj'],
#  ['recorde', 'solas', 'estabamos'],
#  ['todo', 'sentirnos', 'podriamos', 'hacer', 'quisieramos', 'culpables'],
#  ['nadie', 'se', 'enteraria'],
#  ['yo', 'menos', 'pensaba', 'al', 'eso'],
#  ['uhm'],
#  ['pondremos', 'diversion', 'esto', 'poco', 'un'],
#  ['me', 'dices'],
#  ['hannah', 'serio'],
#  ['whisky'],
#  ['loca'],
#  ['pensando'],
#  ['courtney', 'trago', 'un', 'solo', 'vamos', 'sera'],
#  ['acuerdo'],
#  ['solo', 'uno'],
#  ['acosador', 'atrapar', 'tenemos', 'tu', 'porque'],
#  ['ya', 'si', 'se'],
#  ['trago', 'solo', 'fueron', 'un'],
#  ['mas', 'tal', 'vez', 'o', 'eso'],
#  ['mas',
#   'encontrabamos',
#   'mi',
#   'un',
#   'haciendo',
#   'poco',
#   'tomado',
#   'tonteras',
#   'habitacion',
#   'habiamos'],
#  ['borrachas', 'muy', 'estabamos'],
#  ['sacarte', 'reto', 'hannah', 'te', 'brasier'],
#  [],
#  ['debajo', 'tranquila', 'blusa'],
#  ['listo'],
#  ['sacarte', 'yo', 'reto', 'ahora', 'ti', 'blusa', 'te'],
#  ['listo'],
#  ['me', 'reto', 'ahora', 'beses', 'te'],
#  ['courtney'],
#  ['no'],
#  ['hannah', 'vamos'],
#  ['un', 'solo', 'tonto', 'reto'],
#  ['va'],
#  ['despues',
#   'comenzaste',
#   'acercaste',
#   'ese',
#   'realmente',
#   'si',
#   'besarme',
#   'asi',
#   'le',
#   'beso',
#   'llamar',
#   'te',
#   'puedo'],
#  ['te', 'yo', 'solo', 'segui'],
#  ['mala', 'idea'],
#  ['mi', 'completo', 'olvidamos', 'acosador'],
#  ['nosotras', 'flash', 'y', 'un', 'senti'],
#  ['si'],
#  ['una', 'nosotras', 'foto'],
#  ['besandonos'],
#  ['quite', 'linterna', 'encima', 'mio', 'afuera', 'apunte', 'te'],
#  ['tyler', 'estaba', 'ahi'],
#  ['tyler'],
#  ['alli', 'haces'],
#  ['acaso', 'espiabas'],
#  ['momento', 'salio', 'ese', 'y', 'tyler', 'corriendo'],
#  ['cama', 'aun', 'seguias'],
#  ['estabas', 'alterada'],
#  ['hannah'],
#  ['yo'],
#  ['deberia', 'irme'],
#  ['esto', 'siento'],
#  ['error', 'fue', 'un'],
#  ['no', 'hecho', 'debi', 'haberlo'],
#  ['no', 'courtney', 'espera'],
#  ['fuiste', 'tu', 'y', 'corriendo', 'te'],
#  ['ya', 'escuela', 'sabia', 'al', 'siguiente', 'foto', 'toda', 'dia'],
#  ['miedo', 'tuviste', 'dime'],
#  ['momento', 'mi', 'vi', 'un', 'llorando', 'corriendo', 'estabas', 'venias'],
#  ['courtney'],
#  ['ocurre'],
#  ['bien'],
#  ['enteras', 'aun', 'te', 'no'],
#  ['hablar', 'paran', 'todos', 'no', 'saben', 'eso', 'foto'],
#  [],
#  ['posible'],
#  ['maldito', 'tyler'],
#  ['ya', 'amigas', 'hannah', 'creo', 'seamos', 'mejor', 'no', 'sabes'],
#  ['sospechar', 'comenzar', 'podrian'],
#  ['courtney', 'nosotras', 'no', 'somos', 'nota', 'se'],
#  ['ademas', 'borrachas', 'estabamos'],
#  ['haciendo', 'sabiamos', 'no', 'estabamos'],
#  ['hannah', 'no', 'siento', 'adios'],
#  ['no', 'me', 'busques'],
#  ['comence', 'llorar'],
#  ['primer', 'mi', 'alli', 'amiga', 'iba', 'se'],
#  ['fuiste', 'te', 'corriendo'],
#  ['pasado', 'saber', 'habia', 'no', 'querias', 'nada'],
#  ['siquiera', 'me', 'mirabas', 'ni'],
#  ['me', 'ignoraste', 'completo', 'mes', 'un', 'entero'],
#  ['dolio', 'me', 'eso'],
#  ['primer', 'mi', 'habias', 'amiga', 'sido'],
#  ['yo', 'y', 'feliz', 'muy', 'estaba', 'eso'],
#  ['arruino', 'tyler', 'amistad', 'nuestra'],
#  ['pasado',
#   'decidiste',
#   'hubieramos',
#   'habia',
#   'superado',
#   'dejarme',
#   'juntas',
#   'solo',
#   'lado'],
#  ['hablar',
#   'sucedido',
#   'tenia',
#   'esperanza',
#   'algun',
#   'acercaras',
#   'te',
#   'dia'],
#  ['nunca', 'hiciste'],
#  ['hicieras', 'me', 'acaso', 'excluyeras', 'malo', 'hice', 'te', 'eso'],
#  ['san', 'todo', 'empieza', 'un', 'dolar', 'valentin'],
#  ['recuerdas'],
#  ['no'],
#  ['ayudare', 'te', 'recordarlo'],
#  ['san',
#   'escuela',
#   'hoja',
#   'repartieron',
#   'un',
#   'dolar',
#   'llegue',
#   'valentin',
#   'cuando',
#   'manana'],
#  ['yo', 'tomara', 'datos', 'fui', 'mis', 'sheri', 'llene', 'resultados'],
#  ['hola', 'hannah'],
#  ['hola', 'sheri'],
#  ['gracias', 'bien'],
#  ['del', 'resultados', 'tomar', 'test'],
#  ['hoja', 'si', 'aqui', 'tienes'],
#  ['gracias'],
#  ['tomara', 'unos', 'segundos'],
#  ['acuerdo'],
#  ['salio', 'hoja', 'elegir', 'sabia', 'no', 'cual', 'cuando'],
#  ['salido', 'han', 'hannah', 'quienes', 'te'],
#  ['si', 'quieres', 'elegir', 'uno', 'ayudarte', 'puedo'],
#  ['bien', 'vale'],
#  ['veamos'],
#  ['walker', 'no', 'bryce', 'definitivamente'],
#  ['tal', 'marcus', 'vez', 'parece', 'cole', 'te'],
#  ['buena', 'creo', 'gente'],
#  ...]

# %%
token_count = sum([len(sentence) for sentence in sentences])
print("Los textos contienen {0:,} tokens".format(token_count))
# Out:
# Los textos contienen 36,084 tokens

# %%
#Numero de dimensiones que va a ejecutar
#mas = a mas generalizado ya que es mas complejo
num_features =800

#Número minimo de palabras a tomar en cuenta
min_word_count=5

#Numero de threads a correr en parallelo
workers = multiprocessing.cpu_count()

#Tamaño de tu ventana cuantas palabras a la vez
context_size = 7

#Agrupamiento de palabras frecuentes a descartar
downsampling = 1e-2

#Posición aleatorio para empezar a vectorizar
#Determinista
seed = 700

#Numero de interaciones a considerar
itera=15
#Implementa la funcion de softmax
hs=1
negative=0

# %%
entrenamiento = w2v.Word2Vec(sentences,
    sg=1,
    seed=seed,
    workers=workers,
    size=num_features,
    min_count=min_word_count,
    window=context_size,
    sample=downsampling,
    iter=itera,
    hs=1,
    negative=0 
)

# %%
#entrenamiento.build_vocab(sentences)

# %%
#entrenamiento.train(sentences, total_examples=len(sentences), epochs=7)

# %%
#Visualizar un vector de 300 en 2 dimensiones
tsne = sklearn.manifold.TSNE(n_components=2, random_state=0)
all_word_vectors_matrix = entrenamiento.wv.vectors

# %%
all_word_vectors_matrix_2d = tsne.fit_transform(all_word_vectors_matrix)

# %%
points = pd.DataFrame(
    [
        (word, coords[0], coords[1])
        for word, coords in [
            (word, all_word_vectors_matrix_2d[entrenamiento.wv.vocab[word].index])
            for word in entrenamiento.wv.vocab
        ]
    ],
    columns=["word","x","y"]
)

# %%
points.head(10)
# Out:
#         word          x          y
# 0      gente  16.197565 -24.066603
# 1      menos  26.014595  -1.478512
# 2     jodido  29.225391 -13.332930
# 3         no -37.944134  17.207676
# 4  necesitas  29.780491 -12.150997
# 5      dejes   6.193478 -13.621235
# 6        vea  33.591572 -15.918269
# 7      nadie  35.776516 -17.690546
# 8   muriendo -31.280989  13.385468
# 9     estaba -20.137796   2.366625

# %%
sns.set_context("poster")

# %%
points.plot.scatter("x", "y", s=10, figsize=(20, 12))

# %%
def plot_region(x_bounds, y_bounds):
    slice = points[
        (x_bounds[0] <= points.x) &
        (points.x <= x_bounds[1]) & 
        (y_bounds[0] <= points.y) &
        (points.y <= y_bounds[1])
    ]
        
    ax = slice.plot.scatter("x", "y", s=35, figsize=(10, 8))
    for i, point in slice.iterrows():
        ax.text(point.x + 0.005, point.y + 0.005, point.word, fontsize=11)

# %%
plot_region(x_bounds=(-2,5, 0.0), y_bounds=(0.0, 2.0))

# %%
entrenamiento.wv.most_similar("suicida")
# Out:
# [('carino', 0.9193066954612732),
#  ('especial', 0.871713399887085),
#  ('habiendo', 0.8302916288375854),
#  ('extranan', 0.8290945291519165),
#  ('hermosa', 0.8288440108299255),
#  ('jode', 0.8250346183776855),
#  ('sexual', 0.8242459297180176),
#  ('jodido', 0.8238567113876343),
#  ('fin', 0.8223620653152466),
#  ('nuestra', 0.8198443055152893)]

# %%
entrenamiento.wv.similarity('suicida', 'morir')
# Out:
# 0.47760623051076984

# %%
import sklearn
from sklearn.naive_bayes import BernoulliNB, GaussianNB, MultinomialNB
from sklearn.model_selection import train_test_split

from sklearn import metrics
from sklearn.metrics import accuracy_score

# %%
entrenamiento.score([limpia_impureza("Adios mundo cruel")])
# Out:
# array([-13.717989], dtype=float32)
